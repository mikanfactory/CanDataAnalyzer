# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.mixture import BayesianGaussianMixture

# %%
import seaborn as sns
sns.set(color_codes=True)

# %% [markdown]
# # Preprocess

# %%
targetDir = "../data/output/Result1/Result/"
speedDir = "../data/output/Result1/Speed/"
brakeDir = "../data/output/Result1/Brake/"
accelDIr = "../data/output/Result1/Accel/"
accelOffDir = "../data/output/Result1/AccelOff/"
steeringPositiveDir = "../data/output/Result1/TurnRight/"
steeringNegativeDir = "../data/output/Result1/TurnLeft/"
manyCarDir = "../data/output/Result1/ManyCars/"
middleCarDir = "../data/output/Result1/MiddleCars/"
lessCarDir = "../data/output/Result1/LessCars/"
afternoonSunMax = "../data/output/Result1/AfternoonSunMax/"
afternoonSunMiddle = "../data/output/Result1/AfternoonSunMiddle/"
afternoonSunMin = "../data/output/Result1/AfternoonSunMin/"
cloudMax = "../data/output/Result1/CloudMax/"
cloudMiddle = "../data/output/Result1/CloudMiddle/"
cloudMin = "../data/output/Result1/CloudMin/"
segmentDir = "../data/output/Result1/Segment/"

# %%
df1 = pd.read_csv(speedDir + "result.csv")
df1.columns = [["id", "slow", "green", "yellow", "red"]]
df2 = pd.read_csv(brakeDir + "result.csv")
df2.columns = [["id", "brake"]]
df3 = pd.read_csv(accelDIr + "result.csv")
df3.columns = [["id", "accel"]]
df4 = pd.read_csv(steeringPositiveDir + "result.csv")
df4.columns = [["id", "turnRight"]]
df5 = pd.read_csv(steeringNegativeDir + "result.csv")
df5.columns = [["id", "turnLeft"]]
df6 = pd.read_csv(afternoonSunMax + "result.csv")
df6.columns = [["id", "sunMax"]]
df7 = pd.read_csv(afternoonSunMiddle + "result.csv")
df7.columns = [["id", "sunMiddle"]]
df8 = pd.read_csv(afternoonSunMin + "result.csv")
df8.columns = [["id", "sunMin"]]
df9 = pd.read_csv(cloudMax + "result.csv")
df9.columns = [["id", "cloudMax"]]
df10 = pd.read_csv(cloudMiddle + "result.csv")
df10.columns = [["id", "cloudMiddle"]]
df11 = pd.read_csv(cloudMin + "result.csv")
df11.columns = [["id", "cloudMin"]]
df12 = pd.read_csv(manyCarDir + "result.csv")
df12.columns = [["id", "manyCars"]]
df13 = pd.read_csv(middleCarDir + "result.csv")
df13.columns = [["id", "middleCars"]]
df14 = pd.read_csv(lessCarDir + "result.csv")
df14.columns = [["id", "lessCars"]]
df15 = pd.read_csv(segmentDir + "result.csv")
df15.columns = [["id", "segmentSize"]]
df16 = pd.read_csv(accelOffDir + "result.csv")
df16.columns = [["id", "accelOff"]]

# %%
def mergeFrames(dfs, key="id"):
    if len(dfs) == 0:
        return pd.DataFrame()
    
    acc = dfs[0]
    for df in dfs[1:]:
        acc = pd.merge(acc, df, on="id")
        
    return acc

# %%
df = mergeFrames([df1, df2, df3, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16])
gridSize = len(df)

# %%
features =  [
    "red",
    "brake", "accel", "accelOff",
    "sunMax", "sunMiddle",
    "cloudMax", "cloudMiddle",
    "manyCars", "middleCars",
    "segmentSize"
]

# %%
mf = df[df['red'] + df['yellow'] + df['green'] + df['slow'] > 0]
mf = mf[features]

# %% [markdown]
# # Summation of all statuses and calculate risk

# %%
rows = mf.as_matrix()
mf["sum"] = [np.sum(rows[i][:-1]) for i in range(len(rows))]

# %%
mf["risk"] = mf["sum"] / mf["segmentSize"]

# %%
mf.describe()
# Out:
#               red       brake       accel    accelOff      sunMax   sunMiddle  \
# count  123.000000  123.000000  123.000000  123.000000  123.000000  123.000000
# mean    11.991870    8.634146   18.048780   24.357724  101.243902   83.552846
# std     29.764512   11.072983   14.551691   19.193634  136.674397   94.135776
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    6.000000   10.000000   13.000000   25.500000
# 50%      0.000000    4.000000   15.000000   22.000000   43.000000   57.000000
# 75%      3.000000   13.500000   26.000000   34.500000  139.500000  107.500000
# max    129.000000   57.000000   69.000000  101.000000  729.000000  669.000000
#
#          cloudMax  cloudMiddle    manyCars  middleCars  segmentSize  \
# count  123.000000   123.000000  123.000000  123.000000   123.000000
# mean   134.406504    52.666667   65.414634   36.390244   379.707317
# std    168.708490    51.929755   72.397234   34.061091   551.907805
# min      1.000000     0.000000    0.000000    0.000000     1.000000
# 25%     29.000000    17.000000   21.500000   15.000000   128.500000
# 50%     79.000000    35.000000   37.000000   26.000000   233.000000
# 75%    164.500000    71.000000   89.000000   46.000000   369.500000
# max    914.000000   293.000000  464.000000  209.000000  4241.000000
#
#                sum        risk
# count   123.000000  123.000000
# mean    536.707317    1.615021
# std     546.354262    0.475518
# min       2.000000    0.385286
# 25%     176.000000    1.298769
# 50%     342.000000    1.680152
# 75%     671.500000    1.987613
# max    3125.000000    2.666667

# %%
mf.sort_values("risk", ascending=False)[:15]
# Out:
#      red  brake  accel  accelOff  sunMax  sunMiddle  cloudMax  cloudMiddle  \
# 511    0      0      1         1       0          3         1            2
# 223    0     12      6        17      73         40        80           33
# 249    0     13     40        53     171        185       179          151
# 277    0      0      5         4      15         21        11           17
# 252    0     16     40        54     142        141       170          102
# 633    0      2      4         3      46         24        45           25
# 251    0     10     42        61     146        181       188          133
# 253    0     11     23        26     143        121       161          100
# 482    0      0      2         1      12          7        14            8
# 244    0      1      6         9      47         38        60           19
# 603    0     18     28        28     387         87       460           71
# 214    0      4     15        18     137         83       180           49
# 424   64      0      6        14     121         57       128           69
# 512    0     29     53        77     332        290       359          246
# 224    0      6     19        22     148         77       209           46
#
#      manyCars  middleCars  segmentSize   sum      risk
# 511         0           0            3     8  2.666667
# 223        62          23          142   346  2.436620
# 249       177          73          432  1042  2.412037
# 277        18           3           39    94  2.410256
# 252       130          70          363   865  2.382920
# 633        26           6           77   181  2.350649
# 251       164          69          426   994  2.333333
# 253       136          46          332   767  2.310241
# 482         5           2           23    51  2.217391
# 244        33          13          102   226  2.215686
# 603       129          56          571  1264  2.213660
# 214       104          42          289   632  2.186851
# 424        85          40          269   584  2.171004
# 512       207         100          780  1693  2.170513
# 224        85          31          300   643  2.143333

# %%
top10 = mf.sort_values("risk", ascending=False)[:10]
top10 = top10[features + ["sum"]]

for key in top10.columns:
    if key == "sum":
        continue
    top10[key] = top10[key] / top10["sum"]

top10 = top10[features]
top10Index = top10.index

# %%
top10
# Out:
#      red     brake     accel  accelOff    sunMax  sunMiddle  cloudMax  \
# 511  0.0  0.000000  0.125000  0.125000  0.000000   0.375000  0.125000
# 223  0.0  0.034682  0.017341  0.049133  0.210983   0.115607  0.231214
# 249  0.0  0.012476  0.038388  0.050864  0.164107   0.177543  0.171785
# 277  0.0  0.000000  0.053191  0.042553  0.159574   0.223404  0.117021
# 252  0.0  0.018497  0.046243  0.062428  0.164162   0.163006  0.196532
# 633  0.0  0.011050  0.022099  0.016575  0.254144   0.132597  0.248619
# 251  0.0  0.010060  0.042254  0.061368  0.146881   0.182093  0.189135
# 253  0.0  0.014342  0.029987  0.033898  0.186441   0.157757  0.209909
# 482  0.0  0.000000  0.039216  0.019608  0.235294   0.137255  0.274510
# 244  0.0  0.004425  0.026549  0.039823  0.207965   0.168142  0.265487
#
#      cloudMiddle  manyCars  middleCars  segmentSize
# 511     0.250000  0.000000    0.000000     0.375000
# 223     0.095376  0.179191    0.066474     0.410405
# 249     0.144914  0.169866    0.070058     0.414587
# 277     0.180851  0.191489    0.031915     0.414894
# 252     0.117919  0.150289    0.080925     0.419653
# 633     0.138122  0.143646    0.033149     0.425414
# 251     0.133803  0.164990    0.069416     0.428571
# 253     0.130378  0.177314    0.059974     0.432855
# 482     0.156863  0.098039    0.039216     0.450980
# 244     0.084071  0.146018    0.057522     0.451327

# %%
top10Index
# Out:
# Int64Index([511, 223, 249, 277, 252, 633, 251, 253, 482, 244], dtype='int64')

# %% [markdown]
# # Save

# %%
pred = zip(mf.index, mf["risk"])
result = np.zeros(gridSize)

for index, risk in pred:
    result[index] = risk
    
np.savetxt(targetDir + "risks.csv", result, delimiter=",", fmt="%f")

# %% [markdown]
# # Risk graph order by index

# %%
plt.plot(result)
# plt.ylim(0, 2)
plt.xlabel("Grid index", size="medium")
plt.ylabel("Risk", size="medium")
