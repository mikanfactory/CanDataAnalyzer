# %%
library(grid)
library(rpart)
library(rpart.plot)
library(partykit)
library(lattice)
library(ggplot2)
library(caret)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
set.seed(1)

# %%
jRoadType <- c("都市間高速", "都市高速", "有料道路", "国道", "県道", "主要地方道", "一般道1、一般道2、一般道3", "その他")
jHighSpeeds <- c("都市間高速", "都市高速", "有料道路")

# %%
printf <- function(...) cat(sprintf(...))

# %%
# 利用する特徴量を列挙
valuables <- c("RoadType","CurveAverage","Speed", "Curve100", "Curve150","MaxSpeed","RiskFactor","Curve","DistSignal","Pitch","AheadDistance","AverageVelocity","TimeToCollision","AccelerationSpeed", "Engine", "SteeringAngle", "TimeHeadway", "Jerk", "LaneCount", "DiffAvgSpeed", "EmptinessOfRoad", "RoadFactor")

# %%
# CV value を計算
# dfx: 使用するデータ
# verbose: ログを出力するかどうか
CV <- function(dfx, verbose=FALSE) {        
    # k=5 束の fold を作成
    folds <- createFolds(dfx$flag, k=5)
    
    # 各 fold における結果を格納する変数
    count <- 1
    errs <- c()       # CV 値
    reds <- c()     # 長時間平均 (Red だと予測して実際に Red だったもの)
    blues <- c()    # 長時間平均 (Blue だと予測して実際に Blue だったもの)
    for (ids in folds) {
        train <- dfx[-ids, ]
        test <- dfx[ids, ]
        fit <- rpart(flag ~ ., data=train, method="class", cp=0.022) # Decision Tree で分類
        p <- predict(fit, newdata=test)                                              # テストデータで予測
        predictedFlags <- colnames(p)[max.col(p, ties.method = "first")]   # 予測確率が一番高いものを選択
        
        # 予測した結果を用いて長期平均を計算
        if (verbose) {
            printf("Fold%d\n", count)
            result <- correctVsPredict(test, predictedFlags, verbose)
            reds <- c(reds, result[1])
            blues <- c(blues, result[2])
            count <- count + 1
            printf("\n")
        } else {
            result <- correctVsPredict(test, predictedFlags, verbose)
            reds <- c(reds, result[1])
            blues <- c(blues, result[2])
        }
        
        nerr <- sum(predictedFlags != test$flag)
        errs <- c(errs, nerr / nrow(test))
    }
    
    c(mean(errs), mean(reds), mean(blues))
}

# %%
# 長時間平均を計算する
correctVsPredict <- function(test, predictedFlags, verbose=FALSE) {    
    # for Red
    predictedRedRows <- test[predictedFlags == "Red", ]
    nCorrectReds <- sum(predictedRedRows$flag == 'Red')
    nPredictedReds <- nrow(predictedRedRows)
    
    # for Blue
    predictedBlueRows <- test[predictedFlags == "Blue", ]
    nCorrectBlues <- sum(predictedBlueRows$flag == 'Blue')
    nPredictedBlues <- nrow(predictedBlueRows)
        
    if (verbose) {
        printf("As for Red: correct/predict = %d/%d = %f\n", nCorrectReds, nPredictedReds, nCorrectReds / nPredictedReds)
        printf("As for Blue: correct/predict = %d/%d = %f\n", nCorrectBlues, nPredictedBlues, nCorrectBlues / nPredictedBlues)  
    }    
    
    c(nCorrectReds/nPredictedReds, nCorrectBlues/nPredictedBlues)
}

# %%
# 全体のうち Red と Blue がどれぐらいの割合かを出力する
printRedRatios <- function(dfx) {
    nRed <- nrow(dfx[dfx$flag == "Red", ])
    nAll <- nrow(dfx)
    printf("Red/All = %d/%d = %f\n", nRed, nAll, nRed/nAll)
    printf("1 - Red/All = %d/%d = %f\n", nAll - nRed, nAll, 1 - nRed/nAll)
}

# %% [markdown]
# # Predict Reds

# %%
df3 <- read.csv("../data/middle/sp5.csv", stringsAsFactors=FALSE)

# %%
df3$flag[df3$flag == "RedA"] <- "Red"
df3$flag[df3$flag == "RedB"] <- "Red"
df3$flag[df3$flag == "BlueA"] <- "Blue"
df3$flag[df3$flag == "BlueB"] <- "Blue"
df3$flag <- as.factor(df3$flag)

# %%
allFeatures <- c(colnames(df3))

# %%
# 存在する RoadType だけ取り出す
roadTypes <- unique(df3$RoadType)

# %%
verbose = FALSE

# %%
# 使用する特徴量だけ抜き取る
df3 <- df3[, c(valuables, "flag")]

# %%
# 各道路タイプに対して CV 値, 長時間平均を計算
for (i in roadTypes) {
    printf("RoadType: %d (%s)\n", i, jRoadType[i+1])
    dfx <- df3[df3$RoadType == i, ]
    result <- CV(dfx, verbose=verbose)
    printRedRatios(dfx)
    printf("Red: Mean correct/predict = %f\n", result[2])
    printf("Blue: Mean correct/predict = %f\n", result[3])
    printf("CV value: %f", result[1])
    printf("\n\n")
}
# Out:
# RoadType: 7 (その他)
# Red/All = 25/27 = 0.925926
# 1 - Red/All = 2/27 = 0.074074
# Red: Mean correct/predict = 0.933333
# Blue: Mean correct/predict = NaN
# CV value: 0.066667
#
# RoadType: 6 (一般道1、一般道2、一般道3)
# Red/All = 90/189 = 0.476190
# 1 - Red/All = 99/189 = 0.523810
# Red: Mean correct/predict = 0.588182
# Blue: Mean correct/predict = 0.608465
# CV value: 0.407255
#
# RoadType: 4 (県道)
# Red/All = 36/71 = 0.507042
# 1 - Red/All = 35/71 = 0.492958
# Red: Mean correct/predict = 0.575794
# Blue: Mean correct/predict = 0.547857
# CV value: 0.437143
#
# RoadType: 5 (主要地方道)
# Red/All = 154/303 = 0.508251
# 1 - Red/All = 149/303 = 0.491749
# Red: Mean correct/predict = 0.595961
# Blue: Mean correct/predict = 0.585389
# CV value: 0.409126
#
# RoadType: 3 (国道)
# Red/All = 202/324 = 0.623457
# 1 - Red/All = 122/324 = 0.376543
# Red: Mean correct/predict = 0.680126
# Blue: Mean correct/predict = 0.495163
# CV value: 0.376250
#
# RoadType: 0 (都市間高速)
# Red/All = 55/81 = 0.679012
# 1 - Red/All = 26/81 = 0.320988
# Red: Mean correct/predict = 0.695455
# Blue: Mean correct/predict = 0.586667
# CV value: 0.368382
#
# RoadType: 2 (有料道路)
# Red/All = 31/47 = 0.659574
# 1 - Red/All = 16/47 = 0.340426
# Red: Mean correct/predict = 0.866667
# Blue: Mean correct/predict = NaN
# CV value: 0.277778

# %% [markdown]
# # Plot Tree

# %%
# 木の表示
set.seed(1)

# %%
for (i in roadTypes) {
    printf("RoadType: %d (%s)\n", i, jRoadType[i+1])
    dfx <- df3[df3$RoadType == i, ]
    
    fit <- rpart(flag ~., data=dfx, method="class", cp=0.022)

    # i = 7 のときは木が作れずエラーになるので回避
    if (i != 7) {
        fname = paste("Dtree-RoadType-", i, ".png", sep="")
        png(fname, height=960, width=960, res=144)   # res=144 で高解像度で保存
        plot(fit, uniform=TRUE, main="Classification Tree")
        text(fit, use.n=TRUE, all=TRUE, cex=.6)
        dev.off()
    }
}
# Out:
# RoadType: 7 (その他)
# RoadType: 6 (一般道1、一般道2、一般道3)
# RoadType: 4 (県道)
# RoadType: 5 (主要地方道)
# RoadType: 3 (国道)
# RoadType: 0 (都市間高速)
# RoadType: 2 (有料道路)

# %% [markdown]
# # Variable importance

# %%
# 特徴量の重要度
set.seed(1)

# %%
for (i in roadTypes) {
    printf("RoadType: %d (%s)\n", i, jRoadType[i+1])
    dfx <- df3[df3$RoadType == i, ]
    
    fit <- rpart(flag ~ ., data=dfx, method="class", cp=0.022)
    
    # i = 7 のときは木が作れずエラーになるので回避
    if (i != 7) {
        summary(fit)
    }
}
# Out:
# RoadType: 7 (その他)
# RoadType: 6 (一般道1、一般道2、一般道3)
# Call:
# rpart(formula = flag ~ ., data = dfx, method = "class", cp = 0.022)
#   n= 189
#
#           CP nsplit rel error    xerror       xstd
# 1 0.27777778      0 1.0000000 1.0000000 0.07628962
# 2 0.07777778      1 0.7222222 0.8111111 0.07437329
# 3 0.06666667      2 0.6444444 0.8111111 0.07437329
# 4 0.05555556      3 0.5777778 0.7666667 0.07354307
# 5 0.02777778      4 0.5222222 0.7111111 0.07228889
# 6 0.02222222      6 0.4666667 0.7222222 0.07255947
# 7 0.02200000      7 0.4444444 0.7666667 0.07354307
#
# Variable importance
#             Pitch      DiffAvgSpeed        DistSignal             Speed
#                20                15                12                11
#     AheadDistance     SteeringAngle      CurveAverage AccelerationSpeed
#                 7                 7                 6                 4
#          MaxSpeed          Curve100   AverageVelocity          Curve150
#                 4                 3                 2                 2
#         LaneCount        RoadFactor       TimeHeadway            Engine
#                 2                 2                 2                 1
#             Curve
#                 1
#
# Node number 1: 189 observations,    complexity param=0.2777778
#   predicted class=Blue  expected loss=0.4761905  P(node) =1
#     class counts:    99    90
#    probabilities: 0.524 0.476
#   left son=2 (128 obs) right son=3 (61 obs)
#   Primary splits:
#       DiffAvgSpeed  < 7.892303    to the right, improve=9.424290, (0 missing)
#       Speed         < 32.85       to the right, improve=9.003605, (0 missing)
#       AheadDistance < 15.4        to the right, improve=7.835404, (0 missing)
#       DistSignal    < 55.97863    to the right, improve=5.723928, (0 missing)
#       SteeringAngle < -5.6        to the right, improve=4.388571, (0 missing)
#   Surrogate splits:
#       Speed           < 30.05       to the right, agree=0.921, adj=0.754, (0 split)
#       AheadDistance   < 16.85       to the right, agree=0.847, adj=0.525, (0 split)
#       MaxSpeed        < 31.46       to the right, agree=0.762, adj=0.262, (0 split)
#       DistSignal      < 52.27579    to the right, agree=0.735, adj=0.180, (0 split)
#       AverageVelocity < 6.441838    to the right, agree=0.735, adj=0.180, (0 split)
#
# Node number 2: 128 observations,    complexity param=0.07777778
#   predicted class=Blue  expected loss=0.3671875  P(node) =0.6772487
#     class counts:    81    47
#    probabilities: 0.633 0.367
#   left son=4 (117 obs) right son=5 (11 obs)
#   Primary splits:
#       SteeringAngle     < -5.8        to the right, improve=4.895408, (0 missing)
#       Pitch             < 0.3447761   to the left,  improve=3.880927, (0 missing)
#       DistSignal        < 24.52628    to the right, improve=3.058957, (0 missing)
#       AccelerationSpeed < -0.2305556  to the right, improve=2.492456, (0 missing)
#       MaxSpeed          < 38.85       to the left,  improve=2.375401, (0 missing)
#   Surrogate splits:
#       Curve100     < 68.5        to the right, agree=0.938, adj=0.273, (0 split)
#       CurveAverage < 67.5        to the right, agree=0.930, adj=0.182, (0 split)
#       Pitch        < -0.5942786  to the right, agree=0.930, adj=0.182, (0 split)
#       Curve        < 100         to the right, agree=0.922, adj=0.091, (0 split)
#
# Node number 3: 61 observations,    complexity param=0.02777778
#   predicted class=Red   expected loss=0.295082  P(node) =0.3227513
#     class counts:    18    43
#    probabilities: 0.295 0.705
#   left son=6 (28 obs) right son=7 (33 obs)
#   Primary splits:
#       Pitch           < -0.02512438 to the left,  improve=2.963629, (0 missing)
#       Engine          < 1253.125    to the left,  improve=2.950984, (0 missing)
#       MaxSpeed        < 25.53       to the left,  improve=2.915511, (0 missing)
#       TimeHeadway     < 2.128279    to the right, improve=2.601539, (0 missing)
#       AverageVelocity < 4.951848    to the left,  improve=2.004408, (0 missing)
#   Surrogate splits:
#       RoadFactor        < 2.5         to the right, agree=0.721, adj=0.393, (0 split)
#       Curve150          < 128         to the left,  agree=0.656, adj=0.250, (0 split)
#       DiffAvgSpeed      < 1.236332    to the right, agree=0.656, adj=0.250, (0 split)
#       DistSignal        < 82.53629    to the left,  agree=0.639, adj=0.214, (0 split)
#       AccelerationSpeed < 0.225       to the right, agree=0.639, adj=0.214, (0 split)
#
# Node number 4: 117 observations,    complexity param=0.06666667
#   predicted class=Blue  expected loss=0.3247863  P(node) =0.6190476
#     class counts:    79    38
#    probabilities: 0.675 0.325
#   left son=8 (107 obs) right son=9 (10 obs)
#   Primary splits:
#       Pitch             < 0.3447761   to the left,  improve=4.938669, (0 missing)
#       DistSignal        < 24.52628    to the right, improve=3.933735, (0 missing)
#       AccelerationSpeed < 0.1583333   to the right, improve=2.692415, (0 missing)
#       DiffAvgSpeed      < 21.38492    to the right, improve=2.410325, (0 missing)
#       Curve             < 158.5       to the left,  improve=1.953602, (0 missing)
#   Surrogate splits:
#       AccelerationSpeed < -0.3416667  to the right, agree=0.932, adj=0.2, (0 split)
#
# Node number 5: 11 observations
#   predicted class=Red   expected loss=0.1818182  P(node) =0.05820106
#     class counts:     2     9
#    probabilities: 0.182 0.818
#
# Node number 6: 28 observations,    complexity param=0.02777778
#   predicted class=Red   expected loss=0.4642857  P(node) =0.1481481
#     class counts:    13    15
#    probabilities: 0.464 0.536
#   left son=12 (21 obs) right son=13 (7 obs)
#   Primary splits:
#       Pitch             < -0.1149254  to the right, improve=4.023810, (0 missing)
#       Engine            < 1259.375    to the left,  improve=3.778571, (0 missing)
#       AccelerationSpeed < 0.2944444   to the left,  improve=2.646520, (0 missing)
#       CurveAverage      < 187         to the right, improve=2.606934, (0 missing)
#       DistSignal        < 21.14829    to the right, improve=1.928571, (0 missing)
#   Surrogate splits:
#       AccelerationSpeed < 0.5555556   to the left,  agree=0.821, adj=0.286, (0 split)
#       TimeHeadway       < 1.674825    to the right, agree=0.821, adj=0.286, (0 split)
#       Curve150          < 84.5        to the right, agree=0.786, adj=0.143, (0 split)
#
# Node number 7: 33 observations
#   predicted class=Red   expected loss=0.1515152  P(node) =0.1746032
#     class counts:     5    28
#    probabilities: 0.152 0.848
#
# Node number 8: 107 observations,    complexity param=0.05555556
#   predicted class=Blue  expected loss=0.2803738  P(node) =0.5661376
#     class counts:    77    30
#    probabilities: 0.720 0.280
#   left son=16 (96 obs) right son=17 (11 obs)
#   Primary splits:
#       DistSignal      < 24.52628    to the right, improve=4.897267, (0 missing)
#       DiffAvgSpeed    < 21.38492    to the right, improve=2.192063, (0 missing)
#       AverageVelocity < 26.75318    to the left,  improve=1.985838, (0 missing)
#       CurveAverage    < 245         to the left,  improve=1.828316, (0 missing)
#       SteeringAngle   < 1.75        to the left,  improve=1.493835, (0 missing)
#   Surrogate splits:
#       Curve100     < 70.5        to the right, agree=0.916, adj=0.182, (0 split)
#       CurveAverage < 69.5        to the right, agree=0.907, adj=0.091, (0 split)
#
# Node number 9: 10 observations
#   predicted class=Red   expected loss=0.2  P(node) =0.05291005
#     class counts:     2     8
#    probabilities: 0.200 0.800
#
# Node number 12: 21 observations,    complexity param=0.02222222
#   predicted class=Blue  expected loss=0.3809524  P(node) =0.1111111
#     class counts:    13     8
#    probabilities: 0.619 0.381
#   left son=24 (7 obs) right son=25 (14 obs)
#   Primary splits:
#       CurveAverage < 182.5       to the right, improve=3.047619, (0 missing)
#       Curve        < 247.5       to the right, improve=2.571429, (0 missing)
#       DistSignal   < 23.78135    to the right, improve=2.333333, (0 missing)
#       Engine       < 1379.688    to the left,  improve=1.832035, (0 missing)
#       RiskFactor   < 0.4925392   to the left,  improve=1.539377, (0 missing)
#   Surrogate splits:
#       DistSignal < 74.08646    to the right, agree=0.810, adj=0.429, (0 split)
#       LaneCount  < 2.5         to the right, agree=0.810, adj=0.429, (0 split)
#       Pitch      < -0.02835821 to the right, agree=0.762, adj=0.286, (0 split)
#       Engine     < 1209.375    to the left,  agree=0.762, adj=0.286, (0 split)
#       Speed      < 11.18       to the left,  agree=0.714, adj=0.143, (0 split)
#
# Node number 13: 7 observations
#   predicted class=Red   expected loss=0  P(node) =0.03703704
#     class counts:     0     7
#    probabilities: 0.000 1.000
#
# Node number 16: 96 observations
#   predicted class=Blue  expected loss=0.2291667  P(node) =0.5079365
#     class counts:    74    22
#    probabilities: 0.771 0.229
#
# Node number 17: 11 observations
#   predicted class=Red   expected loss=0.2727273  P(node) =0.05820106
#     class counts:     3     8
#    probabilities: 0.273 0.727
#
# Node number 24: 7 observations
#   predicted class=Blue  expected loss=0  P(node) =0.03703704
#     class counts:     7     0
#    probabilities: 1.000 0.000
#
# Node number 25: 14 observations
#   predicted class=Red   expected loss=0.4285714  P(node) =0.07407407
#     class counts:     6     8
#    probabilities: 0.429 0.571
#
# RoadType: 4 (県道)
# Call:
# rpart(formula = flag ~ ., data = dfx, method = "class", cp = 0.022)
#   n= 71
#
#           CP nsplit rel error   xerror      xstd
# 1 0.20000000      0 1.0000000 1.314286 0.1149878
# 2 0.12857143      1 0.8000000 1.257143 0.1168721
# 3 0.04285714      3 0.5428571 1.057143 0.1202661
# 4 0.02200000      5 0.4571429 1.085714 0.1200747
#
# Variable importance
#           Speed    DiffAvgSpeed    CurveAverage        MaxSpeed        Curve100
#              14              10              10              10               8
# EmptinessOfRoad AverageVelocity   AheadDistance        Curve150          Engine
#               8               8               7               6               6
#      DistSignal           Curve   SteeringAngle           Pitch TimeToCollision
#               5               2               2               2               2
#      RiskFactor
#               1
#
# Node number 1: 71 observations,    complexity param=0.2
#   predicted class=Red   expected loss=0.4929577  P(node) =1
#     class counts:    35    36
#    probabilities: 0.493 0.507
#   left son=2 (9 obs) right son=3 (62 obs)
#   Primary splits:
#       EmptinessOfRoad < 0.5241361    to the right, improve=3.231309, (0 missing)
#       Curve100        < 244.5        to the right, improve=2.816035, (0 missing)
#       Jerk            < 1.388889     to the left,  improve=2.441370, (0 missing)
#       AheadDistance   < 14.25        to the right, improve=2.420494, (0 missing)
#       CurveAverage    < 114.5        to the right, improve=1.997876, (0 missing)
#
# Node number 2: 9 observations
#   predicted class=Blue  expected loss=0.1111111  P(node) =0.1267606
#     class counts:     8     1
#    probabilities: 0.889 0.111
#
# Node number 3: 62 observations,    complexity param=0.1285714
#   predicted class=Red   expected loss=0.4354839  P(node) =0.8732394
#     class counts:    27    35
#    probabilities: 0.435 0.565
#   left son=6 (54 obs) right son=7 (8 obs)
#   Primary splits:
#       Curve100        < 160.5        to the right, improve=3.483871, (0 missing)
#       CurveAverage    < 142          to the right, improve=2.683871, (0 missing)
#       DiffAvgSpeed    < 22.06687     to the left,  improve=2.194509, (0 missing)
#       Speed           < 37.6         to the left,  improve=2.150538, (0 missing)
#       TimeToCollision < 222.0519     to the left,  improve=2.000538, (0 missing)
#   Surrogate splits:
#       CurveAverage < 127          to the right, agree=0.984, adj=0.875, (0 split)
#       Curve150     < 122.5        to the right, agree=0.968, adj=0.750, (0 split)
#       DistSignal   < 133.1836     to the left,  agree=0.952, adj=0.625, (0 split)
#       Speed        < 37.6         to the left,  agree=0.935, adj=0.500, (0 split)
#       MaxSpeed     < 48.64        to the left,  agree=0.935, adj=0.500, (0 split)
#
# Node number 6: 54 observations,    complexity param=0.1285714
#   predicted class=Blue  expected loss=0.5  P(node) =0.7605634
#     class counts:    27    27
#    probabilities: 0.500 0.500
#   left son=12 (31 obs) right son=13 (23 obs)
#   Primary splits:
#       AheadDistance < 14.25        to the right, improve=3.067321, (0 missing)
#       MaxSpeed      < 34.315       to the right, improve=2.373626, (0 missing)
#       TimeHeadway   < 2.205337     to the right, improve=2.209091, (0 missing)
#       LaneCount     < 2.5          to the left,  improve=2.103339, (0 missing)
#       Pitch         < 0.001741294  to the right, improve=1.989474, (0 missing)
#   Surrogate splits:
#       Speed           < 22.02        to the right, agree=0.852, adj=0.652, (0 split)
#       DiffAvgSpeed    < 4.31187      to the right, agree=0.852, adj=0.652, (0 split)
#       Engine          < 1154.688     to the right, agree=0.759, adj=0.435, (0 split)
#       AverageVelocity < 8.293851     to the right, agree=0.741, adj=0.391, (0 split)
#       MaxSpeed        < 30.605       to the right, agree=0.704, adj=0.304, (0 split)
#
# Node number 7: 8 observations
#   predicted class=Red   expected loss=0  P(node) =0.1126761
#     class counts:     0     8
#    probabilities: 0.000 1.000
#
# Node number 12: 31 observations,    complexity param=0.04285714
#   predicted class=Blue  expected loss=0.3548387  P(node) =0.4366197
#     class counts:    20    11
#    probabilities: 0.645 0.355
#   left son=24 (7 obs) right son=25 (24 obs)
#   Primary splits:
#       DiffAvgSpeed    < 7.761568     to the left,  improve=2.276882, (0 missing)
#       AverageVelocity < 19.20334     to the right, improve=1.917358, (0 missing)
#       Curve100        < 231          to the right, improve=1.573983, (0 missing)
#       Pitch           < -0.003109453 to the right, improve=1.573983, (0 missing)
#       DistSignal      < 89.49884     to the right, improve=1.506680, (0 missing)
#   Surrogate splits:
#       Speed           < 20.02        to the left,  agree=0.903, adj=0.571, (0 split)
#       Engine          < 1039.062     to the left,  agree=0.871, adj=0.429, (0 split)
#       Pitch           < 0.1094527    to the right, agree=0.839, adj=0.286, (0 split)
#       TimeToCollision < 13.84362     to the left,  agree=0.839, adj=0.286, (0 split)
#       RiskFactor      < 0.6660513    to the right, agree=0.806, adj=0.143, (0 split)
#
# Node number 13: 23 observations
#   predicted class=Red   expected loss=0.3043478  P(node) =0.3239437
#     class counts:     7    16
#    probabilities: 0.304 0.696
#
# Node number 24: 7 observations
#   predicted class=Blue  expected loss=0  P(node) =0.09859155
#     class counts:     7     0
#    probabilities: 1.000 0.000
#
# Node number 25: 24 observations,    complexity param=0.04285714
#   predicted class=Blue  expected loss=0.4583333  P(node) =0.3380282
#     class counts:    13    11
#    probabilities: 0.542 0.458
#   left son=50 (7 obs) right son=51 (17 obs)
#   Primary splits:
#       AverageVelocity < 19.20334     to the right, improve=1.967087, (0 missing)
#       TimeHeadway     < 2.56816      to the left,  improve=1.967087, (0 missing)
#       Curve100        < 231          to the right, improve=1.294818, (0 missing)
#       MaxSpeed        < 34.22        to the right, improve=1.294818, (0 missing)
#       SteeringAngle   < 3.85         to the left,  improve=1.294818, (0 missing)
#   Surrogate splits:
#       MaxSpeed      < 42.165       to the right, agree=0.917, adj=0.714, (0 split)
#       CurveAverage  < 163.5        to the left,  agree=0.875, adj=0.571, (0 split)
#       Curve         < 166.5        to the left,  agree=0.833, adj=0.429, (0 split)
#       SteeringAngle < -2.2         to the left,  agree=0.833, adj=0.429, (0 split)
#       Speed         < 41.225       to the right, agree=0.792, adj=0.286, (0 split)
#
# Node number 50: 7 observations
#   predicted class=Blue  expected loss=0.1428571  P(node) =0.09859155
#     class counts:     6     1
#    probabilities: 0.857 0.143
#
# Node number 51: 17 observations
#   predicted class=Red   expected loss=0.4117647  P(node) =0.2394366
#     class counts:     7    10
#    probabilities: 0.412 0.588
#
# RoadType: 5 (主要地方道)
# Call:
# rpart(formula = flag ~ ., data = dfx, method = "class", cp = 0.022)
#   n= 303
#
#           CP nsplit rel error    xerror       xstd
# 1 0.28187919      0 1.0000000 1.1409396 0.05797526
# 2 0.05369128      1 0.7181208 0.8187919 0.05729433
# 3 0.04697987      2 0.6644295 0.8389262 0.05751186
# 4 0.02684564      4 0.5704698 0.8389262 0.05751186
# 5 0.02348993      5 0.5436242 0.8389262 0.05751186
# 6 0.02200000      7 0.4966443 0.8389262 0.05751186
#
# Variable importance
#       TimeHeadway AccelerationSpeed             Speed        RiskFactor
#                15                14                 9                 9
#     AheadDistance      DiffAvgSpeed     SteeringAngle        DistSignal
#                 8                 7                 7                 6
#          MaxSpeed              Jerk            Engine   AverageVelocity
#                 6                 4                 4                 4
#   TimeToCollision      CurveAverage   EmptinessOfRoad          Curve100
#                 2                 1                 1                 1
#          Curve150
#                 1
#
# Node number 1: 303 observations,    complexity param=0.2818792
#   predicted class=Red   expected loss=0.4917492  P(node) =1
#     class counts:   149   154
#    probabilities: 0.492 0.508
#   left son=2 (180 obs) right son=3 (123 obs)
#   Primary splits:
#       TimeHeadway   < 2.54646     to the right, improve=13.838420, (0 missing)
#       RiskFactor    < 0.4613778   to the left,  improve=12.077870, (0 missing)
#       Engine        < 1573.438    to the left,  improve= 5.508925, (0 missing)
#       Pitch         < -0.1822139  to the left,  improve= 5.342705, (0 missing)
#       SteeringAngle < 4.65        to the left,  improve= 5.105731, (0 missing)
#   Surrogate splits:
#       RiskFactor      < 0.4613778   to the left,  agree=0.828, adj=0.577, (0 split)
#       TimeToCollision < 18.94956    to the right, agree=0.660, adj=0.163, (0 split)
#       AheadDistance   < 24.85       to the right, agree=0.640, adj=0.114, (0 split)
#       EmptinessOfRoad < 0.236005    to the right, agree=0.627, adj=0.081, (0 split)
#       AverageVelocity < 29.73778    to the left,  agree=0.624, adj=0.073, (0 split)
#
# Node number 2: 180 observations,    complexity param=0.05369128
#   predicted class=Blue  expected loss=0.3833333  P(node) =0.5940594
#     class counts:   111    69
#    probabilities: 0.617 0.383
#   left son=4 (170 obs) right son=5 (10 obs)
#   Primary splits:
#       AccelerationSpeed < 0.6027778   to the left,  improve=5.652941, (0 missing)
#       SteeringAngle     < 8.65        to the left,  improve=5.207143, (0 missing)
#       DistSignal        < 58.51371    to the right, improve=4.195134, (0 missing)
#       Speed             < 6.58        to the right, improve=4.047674, (0 missing)
#       Engine            < 1573.438    to the left,  improve=3.457143, (0 missing)
#   Surrogate splits:
#       SteeringAngle < 18.05       to the left,  agree=0.972, adj=0.5, (0 split)
#       Engine        < 1704.688    to the left,  agree=0.961, adj=0.3, (0 split)
#       Speed         < 5.655       to the right, agree=0.950, adj=0.1, (0 split)
#
# Node number 3: 123 observations,    complexity param=0.02348993
#   predicted class=Red   expected loss=0.3089431  P(node) =0.4059406
#     class counts:    38    85
#    probabilities: 0.309 0.691
#   left son=6 (27 obs) right son=7 (96 obs)
#   Primary splits:
#       Jerk              < -0.1944444  to the left,  improve=3.038844, (0 missing)
#       AccelerationSpeed < -0.2638889  to the left,  improve=2.485237, (0 missing)
#       MaxSpeed          < 61.105      to the left,  improve=2.005510, (0 missing)
#       Pitch             < 0.02350746  to the right, improve=1.842221, (0 missing)
#       Engine            < 1631.25     to the left,  improve=1.633369, (0 missing)
#   Surrogate splits:
#       AccelerationSpeed < -0.3416667  to the left,  agree=0.789, adj=0.037, (0 split)
#
# Node number 4: 170 observations,    complexity param=0.04697987
#   predicted class=Blue  expected loss=0.3529412  P(node) =0.5610561
#     class counts:   110    60
#    probabilities: 0.647 0.353
#   left son=8 (110 obs) right son=9 (60 obs)
#   Primary splits:
#       DistSignal      < 58.51371    to the right, improve=4.971301, (0 missing)
#       Speed           < 49.365      to the left,  improve=3.321510, (0 missing)
#       TimeToCollision < 26.81701    to the right, improve=2.942115, (0 missing)
#       Engine          < 960.9375    to the right, improve=2.647059, (0 missing)
#       Jerk            < 1.083333    to the right, improve=2.633749, (0 missing)
#   Surrogate splits:
#       MaxSpeed        < 48.76       to the left,  agree=0.700, adj=0.150, (0 split)
#       Speed           < 50.86       to the left,  agree=0.694, adj=0.133, (0 split)
#       DiffAvgSpeed    < 32.35883    to the left,  agree=0.694, adj=0.133, (0 split)
#       Jerk            < -0.4722222  to the right, agree=0.682, adj=0.100, (0 split)
#       AverageVelocity < 5.227398    to the right, agree=0.676, adj=0.083, (0 split)
#
# Node number 5: 10 observations
#   predicted class=Red   expected loss=0.1  P(node) =0.0330033
#     class counts:     1     9
#    probabilities: 0.100 0.900
#
# Node number 6: 27 observations,    complexity param=0.02348993
#   predicted class=Blue  expected loss=0.4814815  P(node) =0.08910891
#     class counts:    14    13
#    probabilities: 0.519 0.481
#   left son=12 (17 obs) right son=13 (10 obs)
#   Primary splits:
#       SteeringAngle   < 3.3         to the left,  improve=3.222658, (0 missing)
#       TimeHeadway     < 2.213298    to the right, improve=1.814815, (0 missing)
#       EmptinessOfRoad < 0.2716839   to the right, improve=1.814815, (0 missing)
#       Speed           < 41.245      to the left,  improve=1.639376, (0 missing)
#       DiffAvgSpeed    < 20.71147    to the left,  improve=1.639376, (0 missing)
#   Surrogate splits:
#       Speed         < 42.89       to the left,  agree=0.815, adj=0.5, (0 split)
#       CurveAverage  < 183.5       to the right, agree=0.778, adj=0.4, (0 split)
#       MaxSpeed      < 49.97       to the left,  agree=0.778, adj=0.4, (0 split)
#       AheadDistance < 31.55       to the left,  agree=0.778, adj=0.4, (0 split)
#       Curve100      < 236         to the right, agree=0.741, adj=0.3, (0 split)
#
# Node number 7: 96 observations
#   predicted class=Red   expected loss=0.25  P(node) =0.3168317
#     class counts:    24    72
#    probabilities: 0.250 0.750
#
# Node number 8: 110 observations
#   predicted class=Blue  expected loss=0.2636364  P(node) =0.3630363
#     class counts:    81    29
#    probabilities: 0.736 0.264
#
# Node number 9: 60 observations,    complexity param=0.04697987
#   predicted class=Red   expected loss=0.4833333  P(node) =0.1980198
#     class counts:    29    31
#    probabilities: 0.483 0.517
#   left son=18 (42 obs) right son=19 (18 obs)
#   Primary splits:
#       AccelerationSpeed < -0.02777778 to the right, improve=7.125397, (0 missing)
#       DistSignal        < 53.01977    to the left,  improve=4.947059, (0 missing)
#       RiskFactor        < 0.4666245   to the left,  improve=3.526667, (0 missing)
#       TimeToCollision   < 26.81701    to the right, improve=3.008333, (0 missing)
#       Pitch             < -0.00721393 to the left,  improve=2.816667, (0 missing)
#   Surrogate splits:
#       Speed        < 45.03       to the left,  agree=0.817, adj=0.389, (0 split)
#       DiffAvgSpeed < 25.79104    to the left,  agree=0.817, adj=0.389, (0 split)
#       MaxSpeed     < 54.45       to the left,  agree=0.750, adj=0.167, (0 split)
#       Curve150     < 136.5       to the right, agree=0.733, adj=0.111, (0 split)
#       DistSignal   < 57.04044    to the left,  agree=0.733, adj=0.111, (0 split)
#
# Node number 12: 17 observations
#   predicted class=Blue  expected loss=0.2941176  P(node) =0.05610561
#     class counts:    12     5
#    probabilities: 0.706 0.294
#
# Node number 13: 10 observations
#   predicted class=Red   expected loss=0.2  P(node) =0.0330033
#     class counts:     2     8
#    probabilities: 0.200 0.800
#
# Node number 18: 42 observations,    complexity param=0.02684564
#   predicted class=Blue  expected loss=0.3571429  P(node) =0.1386139
#     class counts:    27    15
#    probabilities: 0.643 0.357
#   left son=36 (24 obs) right son=37 (18 obs)
#   Primary splits:
#       AheadDistance   < 23          to the right, improve=4.063492, (0 missing)
#       Speed           < 27.88       to the right, improve=3.813492, (0 missing)
#       MaxSpeed        < 41.24       to the right, improve=3.813492, (0 missing)
#       DiffAvgSpeed    < 7.975177    to the right, improve=3.813492, (0 missing)
#       AverageVelocity < 19.48919    to the right, improve=2.956802, (0 missing)
#   Surrogate splits:
#       DiffAvgSpeed    < 5.771216    to the right, agree=0.905, adj=0.778, (0 split)
#       Speed           < 25.92       to the right, agree=0.881, adj=0.722, (0 split)
#       MaxSpeed        < 27.46       to the right, agree=0.762, adj=0.444, (0 split)
#       AverageVelocity < 5.420944    to the right, agree=0.762, adj=0.444, (0 split)
#       Engine          < 1262.5      to the right, agree=0.762, adj=0.444, (0 split)
#
# Node number 19: 18 observations
#   predicted class=Red   expected loss=0.1111111  P(node) =0.05940594
#     class counts:     2    16
#    probabilities: 0.111 0.889
#
# Node number 36: 24 observations
#   predicted class=Blue  expected loss=0.1666667  P(node) =0.07920792
#     class counts:    20     4
#    probabilities: 0.833 0.167
#
# Node number 37: 18 observations
#   predicted class=Red   expected loss=0.3888889  P(node) =0.05940594
#     class counts:     7    11
#    probabilities: 0.389 0.611
#
# RoadType: 3 (国道)
# Call:
# rpart(formula = flag ~ ., data = dfx, method = "class", cp = 0.022)
#   n= 324
#
#           CP nsplit rel error   xerror       xstd
# 1 0.06557377      0 1.0000000 1.000000 0.07148637
# 2 0.03278689      2 0.8688525 1.090164 0.07257886
# 3 0.02459016      4 0.8032787 1.090164 0.07257886
# 4 0.02200000      6 0.7540984 1.131148 0.07295645
#
# Variable importance
#       TimeHeadway        RiskFactor     AheadDistance     SteeringAngle
#                13                12                11                10
#      CurveAverage        DistSignal             Curve AccelerationSpeed
#                 9                 7                 6                 6
#   EmptinessOfRoad          Curve100   TimeToCollision          Curve150
#                 6                 5                 5                 4
#          MaxSpeed   AverageVelocity             Speed      DiffAvgSpeed
#                 2                 2                 1                 1
#
# Node number 1: 324 observations,    complexity param=0.06557377
#   predicted class=Red   expected loss=0.3765432  P(node) =1
#     class counts:   122   202
#    probabilities: 0.377 0.623
#   left son=2 (222 obs) right son=3 (102 obs)
#   Primary splits:
#       CurveAverage      < 134.5       to the right, improve=5.144125, (0 missing)
#       AheadDistance     < 15.9        to the right, improve=5.108362, (0 missing)
#       DistSignal        < 47.17896    to the right, improve=4.930376, (0 missing)
#       AccelerationSpeed < 0.4638889   to the left,  improve=4.235277, (0 missing)
#       RiskFactor        < 0.4622222   to the left,  improve=4.040409, (0 missing)
#   Surrogate splits:
#       Curve         < 155.5       to the right, agree=0.849, adj=0.520, (0 split)
#       Curve100      < 164.5       to the right, agree=0.812, adj=0.402, (0 split)
#       Curve150      < 134         to the right, agree=0.753, adj=0.216, (0 split)
#       SteeringAngle < 5.9         to the left,  agree=0.738, adj=0.167, (0 split)
#       MaxSpeed      < 22.6        to the right, agree=0.713, adj=0.088, (0 split)
#
# Node number 2: 222 observations,    complexity param=0.06557377
#   predicted class=Red   expected loss=0.4369369  P(node) =0.6851852
#     class counts:    97   125
#    probabilities: 0.437 0.563
#   left son=4 (26 obs) right son=5 (196 obs)
#   Primary splits:
#       AheadDistance     < 47.4        to the right, improve=8.096087, (0 missing)
#       AccelerationSpeed < 0.4527778   to the left,  improve=6.142447, (0 missing)
#       Speed             < 34.185      to the right, improve=5.398679, (0 missing)
#       DiffAvgSpeed      < 12.49078    to the right, improve=4.655304, (0 missing)
#       DistSignal        < 47.17896    to the right, improve=4.637797, (0 missing)
#   Surrogate splits:
#       RiskFactor      < 0.1331215   to the left,  agree=0.950, adj=0.577, (0 split)
#       TimeHeadway     < 10.07098    to the right, agree=0.950, adj=0.577, (0 split)
#       EmptinessOfRoad < 0.247239    to the right, agree=0.946, adj=0.538, (0 split)
#       TimeToCollision < 0.9992708   to the left,  agree=0.905, adj=0.192, (0 split)
#       DiffAvgSpeed    < 50.25136    to the right, agree=0.896, adj=0.115, (0 split)
#
# Node number 3: 102 observations,    complexity param=0.03278689
#   predicted class=Red   expected loss=0.245098  P(node) =0.3148148
#     class counts:    25    77
#    probabilities: 0.245 0.755
#   left son=6 (28 obs) right son=7 (74 obs)
#   Primary splits:
#       SteeringAngle   < 1.5         to the left,  improve=5.015368, (0 missing)
#       TimeHeadway     < 2.634762    to the right, improve=4.421866, (0 missing)
#       RiskFactor      < 0.4256425   to the left,  improve=3.452241, (0 missing)
#       Engine          < 1164.062    to the left,  improve=3.309008, (0 missing)
#       AverageVelocity < 19.07851    to the left,  improve=2.712203, (0 missing)
#   Surrogate splits:
#       Curve           < 76.5        to the left,  agree=0.833, adj=0.393, (0 split)
#       CurveAverage    < 76.5        to the left,  agree=0.824, adj=0.357, (0 split)
#       MaxSpeed        < 19.055      to the left,  agree=0.765, adj=0.143, (0 split)
#       AverageVelocity < 6.106334    to the left,  agree=0.765, adj=0.143, (0 split)
#       DistSignal      < 12.2577     to the left,  agree=0.755, adj=0.107, (0 split)
#
# Node number 4: 26 observations
#   predicted class=Blue  expected loss=0.1923077  P(node) =0.08024691
#     class counts:    21     5
#    probabilities: 0.808 0.192
#
# Node number 5: 196 observations,    complexity param=0.02459016
#   predicted class=Red   expected loss=0.3877551  P(node) =0.6049383
#     class counts:    76   120
#    probabilities: 0.388 0.612
#   left son=10 (182 obs) right son=11 (14 obs)
#   Primary splits:
#       AccelerationSpeed < 0.4527778   to the left,  improve=4.533752, (0 missing)
#       DistSignal        < 281.009     to the right, improve=3.581655, (0 missing)
#       AheadDistance     < 15.75       to the right, improve=3.437087, (0 missing)
#       Pitch             < -0.06007463 to the left,  improve=2.989005, (0 missing)
#       Speed             < 34.185      to the right, improve=2.946939, (0 missing)
#   Surrogate splits:
#       Speed         < 7.595       to the right, agree=0.944, adj=0.214, (0 split)
#       RiskFactor    < 0.2411606   to the right, agree=0.939, adj=0.143, (0 split)
#       AheadDistance < 6.8         to the right, agree=0.934, adj=0.071, (0 split)
#       SteeringAngle < 15.75       to the left,  agree=0.934, adj=0.071, (0 split)
#       TimeHeadway   < 4.385853    to the left,  agree=0.934, adj=0.071, (0 split)
#
# Node number 6: 28 observations,    complexity param=0.03278689
#   predicted class=Blue  expected loss=0.5  P(node) =0.08641975
#     class counts:    14    14
#    probabilities: 0.500 0.500
#   left son=12 (14 obs) right son=13 (14 obs)
#   Primary splits:
#       TimeHeadway   < 2.606758    to the right, improve=4.571429, (0 missing)
#       Curve100      < 246         to the left,  improve=2.625000, (0 missing)
#       RiskFactor    < 0.4397304   to the left,  improve=2.625000, (0 missing)
#       Curve150      < 180         to the left,  improve=2.380952, (0 missing)
#       SteeringAngle < -17.65      to the right, improve=2.380952, (0 missing)
#   Surrogate splits:
#       RiskFactor      < 0.4397304   to the left,  agree=0.929, adj=0.857, (0 split)
#       Curve100        < 170.5       to the left,  agree=0.714, adj=0.429, (0 split)
#       Curve150        < 175.5       to the left,  agree=0.714, adj=0.429, (0 split)
#       DistSignal      < 42.89679    to the right, agree=0.714, adj=0.429, (0 split)
#       TimeToCollision < 24.89428    to the right, agree=0.714, adj=0.429, (0 split)
#
# Node number 7: 74 observations
#   predicted class=Red   expected loss=0.1486486  P(node) =0.2283951
#     class counts:    11    63
#    probabilities: 0.149 0.851
#
# Node number 10: 182 observations,    complexity param=0.02459016
#   predicted class=Red   expected loss=0.4175824  P(node) =0.5617284
#     class counts:    76   106
#    probabilities: 0.418 0.582
#   left son=20 (10 obs) right son=21 (172 obs)
#   Primary splits:
#       DistSignal    < 281.009     to the right, improve=3.094914, (0 missing)
#       Pitch         < -0.06007463 to the left,  improve=3.063624, (0 missing)
#       RiskFactor    < 0.4679473   to the left,  improve=2.373626, (0 missing)
#       AheadDistance < 15.75       to the right, improve=1.920661, (0 missing)
#       Curve150      < 236.5       to the right, improve=1.827855, (0 missing)
#   Surrogate splits:
#       SteeringAngle   < -32.2       to the left,  agree=0.967, adj=0.4, (0 split)
#       AverageVelocity < 61.99546    to the right, agree=0.956, adj=0.2, (0 split)
#       MaxSpeed        < 76.355      to the right, agree=0.951, adj=0.1, (0 split)
#
# Node number 11: 14 observations
#   predicted class=Red   expected loss=0  P(node) =0.04320988
#     class counts:     0    14
#    probabilities: 0.000 1.000
#
# Node number 12: 14 observations
#   predicted class=Blue  expected loss=0.2142857  P(node) =0.04320988
#     class counts:    11     3
#    probabilities: 0.786 0.214
#
# Node number 13: 14 observations
#   predicted class=Red   expected loss=0.2142857  P(node) =0.04320988
#     class counts:     3    11
#    probabilities: 0.214 0.786
#
# Node number 20: 10 observations
#   predicted class=Blue  expected loss=0.2  P(node) =0.0308642
#     class counts:     8     2
#    probabilities: 0.800 0.200
#
# Node number 21: 172 observations
#   predicted class=Red   expected loss=0.3953488  P(node) =0.5308642
#     class counts:    68   104
#    probabilities: 0.395 0.605
#
# RoadType: 0 (都市間高速)
# Call:
# rpart(formula = flag ~ ., data = dfx, method = "class", cp = 0.022)
#   n= 81
#
#           CP nsplit rel error   xerror      xstd
# 1 0.15384615      0 1.0000000 1.000000 0.1616040
# 2 0.07692308      1 0.8461538 1.000000 0.1616040
# 3 0.02200000      4 0.6153846 1.115385 0.1659529
#
# Variable importance
#        RiskFactor       TimeHeadway             Speed   TimeToCollision
#                18                13                 9                 9
#            Engine             Pitch          MaxSpeed      DiffAvgSpeed
#                 7                 7                 6                 6
#   AverageVelocity AccelerationSpeed     SteeringAngle     AheadDistance
#                 5                 5                 3                 3
#      CurveAverage              Jerk          Curve100
#                 3                 2                 2
#
# Node number 1: 81 observations,    complexity param=0.1538462
#   predicted class=Red   expected loss=0.3209877  P(node) =1
#     class counts:    26    55
#    probabilities: 0.321 0.679
#   left son=2 (8 obs) right son=3 (73 obs)
#   Primary splits:
#       RiskFactor        < 1.254939    to the right, improve=3.267546, (0 missing)
#       AheadDistance     < 49.35       to the right, improve=1.828642, (0 missing)
#       Engine            < 1626.562    to the left,  improve=1.709861, (0 missing)
#       AccelerationSpeed < 0.3166667   to the right, improve=1.640834, (0 missing)
#       TimeHeadway       < 2.496313    to the right, improve=1.589002, (0 missing)
#   Surrogate splits:
#       TimeToCollision < 8.460442    to the left,  agree=0.975, adj=0.750, (0 split)
#       TimeHeadway     < 0.9022762   to the left,  agree=0.963, adj=0.625, (0 split)
#
# Node number 2: 8 observations
#   predicted class=Blue  expected loss=0.25  P(node) =0.09876543
#     class counts:     6     2
#    probabilities: 0.750 0.250
#
# Node number 3: 73 observations,    complexity param=0.07692308
#   predicted class=Red   expected loss=0.2739726  P(node) =0.9012346
#     class counts:    20    53
#    probabilities: 0.274 0.726
#   left son=6 (48 obs) right son=7 (25 obs)
#   Primary splits:
#       RiskFactor        < 0.7241545   to the left,  improve=2.861096, (0 missing)
#       TimeHeadway       < 2.496313    to the right, improve=2.802835, (0 missing)
#       Engine            < 1540.625    to the left,  improve=2.416662, (0 missing)
#       AccelerationSpeed < 0.3166667   to the right, improve=2.214173, (0 missing)
#       AheadDistance     < 49.35       to the right, improve=2.053574, (0 missing)
#   Surrogate splits:
#       TimeHeadway     < 1.687711    to the right, agree=0.945, adj=0.84, (0 split)
#       AheadDistance   < 19.45       to the right, agree=0.767, adj=0.32, (0 split)
#       TimeToCollision < 22.4099     to the right, agree=0.740, adj=0.24, (0 split)
#       MaxSpeed        < 105.77      to the left,  agree=0.699, adj=0.12, (0 split)
#       CurveAverage    < 55          to the right, agree=0.685, adj=0.08, (0 split)
#
# Node number 6: 48 observations,    complexity param=0.07692308
#   predicted class=Red   expected loss=0.375  P(node) =0.5925926
#     class counts:    18    30
#    probabilities: 0.375 0.625
#   left son=12 (27 obs) right son=13 (21 obs)
#   Primary splits:
#       Speed             < 80.385      to the left,  improve=2.542328, (0 missing)
#       Engine            < 1626.562    to the left,  improve=2.193913, (0 missing)
#       DiffAvgSpeed      < -7.000337   to the left,  improve=1.901739, (0 missing)
#       AccelerationSpeed < 0.1555556   to the right, improve=1.388889, (0 missing)
#       Pitch             < -0.4186567  to the left,  improve=1.200000, (0 missing)
#   Surrogate splits:
#       Engine            < 1640.625    to the left,  agree=0.979, adj=0.952, (0 split)
#       DiffAvgSpeed      < -7.000337   to the left,  agree=0.917, adj=0.810, (0 split)
#       MaxSpeed          < 89.325      to the left,  agree=0.875, adj=0.714, (0 split)
#       AverageVelocity   < 49.22949    to the left,  agree=0.875, adj=0.714, (0 split)
#       AccelerationSpeed < -0.06666667 to the right, agree=0.833, adj=0.619, (0 split)
#
# Node number 7: 25 observations
#   predicted class=Red   expected loss=0.08  P(node) =0.308642
#     class counts:     2    23
#    probabilities: 0.080 0.920
#
# Node number 12: 27 observations,    complexity param=0.07692308
#   predicted class=Blue  expected loss=0.4814815  P(node) =0.3333333
#     class counts:    14    13
#    probabilities: 0.519 0.481
#   left son=24 (16 obs) right son=25 (11 obs)
#   Primary splits:
#       Pitch         < -0.04179104 to the left,  improve=2.242845, (0 missing)
#       Speed         < 60.63       to the right, improve=2.167196, (0 missing)
#       AheadDistance < 20.2        to the right, improve=1.639376, (0 missing)
#       Engine        < 1310.938    to the right, improve=1.639376, (0 missing)
#       MaxSpeed      < 58.04       to the right, improve=1.617845, (0 missing)
#   Surrogate splits:
#       SteeringAngle < 1.55        to the right, agree=0.778, adj=0.455, (0 split)
#       Jerk          < 0.4722222   to the left,  agree=0.741, adj=0.364, (0 split)
#       CurveAverage  < 145         to the left,  agree=0.704, adj=0.273, (0 split)
#       Speed         < 42.43       to the right, agree=0.704, adj=0.273, (0 split)
#       Curve100      < 228         to the left,  agree=0.704, adj=0.273, (0 split)
#
# Node number 13: 21 observations
#   predicted class=Red   expected loss=0.1904762  P(node) =0.2592593
#     class counts:     4    17
#    probabilities: 0.190 0.810
#
# Node number 24: 16 observations
#   predicted class=Blue  expected loss=0.3125  P(node) =0.1975309
#     class counts:    11     5
#    probabilities: 0.688 0.313
#
# Node number 25: 11 observations
#   predicted class=Red   expected loss=0.2727273  P(node) =0.1358025
#     class counts:     3     8
#    probabilities: 0.273 0.727
#
# RoadType: 2 (有料道路)
# Call:
# rpart(formula = flag ~ ., data = dfx, method = "class", cp = 0.022)
#   n= 47
#
#       CP nsplit rel error xerror      xstd
# 1 0.4375      0    1.0000 1.0000 0.2030355
# 2 0.1250      1    0.5625 0.6875 0.1814173
# 3 0.0220      2    0.4375 0.8125 0.1916647
#
# Variable importance
#    DiffAvgSpeed      DistSignal    CurveAverage   AheadDistance           Speed
#              20              19              16              13              12
#           Pitch EmptinessOfRoad        Curve100        Curve150
#               9               4               3               3
#
# Node number 1: 47 observations,    complexity param=0.4375
#   predicted class=Red   expected loss=0.3404255  P(node) =1
#     class counts:    16    31
#    probabilities: 0.340 0.660
#   left son=2 (23 obs) right son=3 (24 obs)
#   Primary splits:
#       DistSignal    < 209.3728    to the right, improve=8.754934, (0 missing)
#       Pitch         < -0.05995025 to the left,  improve=5.873050, (0 missing)
#       Speed         < 50.165      to the right, improve=5.150019, (0 missing)
#       DiffAvgSpeed  < 8.676363    to the right, improve=3.972325, (0 missing)
#       AheadDistance < 25.2        to the right, improve=3.527436, (0 missing)
#   Surrogate splits:
#       DiffAvgSpeed  < 8.676363    to the right, agree=0.851, adj=0.696, (0 split)
#       CurveAverage  < 60.5        to the right, agree=0.830, adj=0.652, (0 split)
#       Speed         < 47.635      to the right, agree=0.809, adj=0.609, (0 split)
#       AheadDistance < 25.2        to the right, agree=0.766, adj=0.522, (0 split)
#       Pitch         < -0.05995025 to the left,  agree=0.745, adj=0.478, (0 split)
#
# Node number 2: 23 observations,    complexity param=0.125
#   predicted class=Blue  expected loss=0.3478261  P(node) =0.4893617
#     class counts:    15     8
#    probabilities: 0.652 0.348
#   left son=4 (11 obs) right son=5 (12 obs)
#   Primary splits:
#       DiffAvgSpeed < 21.54046    to the left,  improve=2.783267, (0 missing)
#       Speed        < 52.185      to the right, improve=2.702640, (0 missing)
#       DistSignal   < 220.0742    to the left,  improve=1.657005, (0 missing)
#       Curve100     < 248         to the left,  improve=1.276052, (0 missing)
#       Curve150     < 209.5       to the left,  improve=1.276052, (0 missing)
#   Surrogate splits:
#       EmptinessOfRoad < 0.4177573   to the right, agree=0.870, adj=0.727, (0 split)
#       CurveAverage    < 153         to the left,  agree=0.783, adj=0.545, (0 split)
#       Curve100        < 104.5       to the left,  agree=0.783, adj=0.545, (0 split)
#       Curve150        < 209.5       to the left,  agree=0.783, adj=0.545, (0 split)
#       AheadDistance   < 77          to the right, agree=0.739, adj=0.455, (0 split)
#
# Node number 3: 24 observations
#   predicted class=Red   expected loss=0.04166667  P(node) =0.5106383
#     class counts:     1    23
#    probabilities: 0.042 0.958
#
# Node number 4: 11 observations
#   predicted class=Blue  expected loss=0.09090909  P(node) =0.2340426
#     class counts:    10     1
#    probabilities: 0.909 0.091
#
# Node number 5: 12 observations
#   predicted class=Red   expected loss=0.4166667  P(node) =0.2553191
#     class counts:     5     7
#    probabilities: 0.417 0.583

# %% [markdown]
# # Threshold = 10, 30

# %%
# さらに Threshold = 10, 30 で分割する
set.seed(1)

# %%
verbose = FALSE

# %%
velocities <- c("slow", "middle", "fast")
for (i in c(5, 3)) {
    threshold1 <- 10
    threshold2 <- 30
    printf("RoadType: %d (%s)\n", i, jRoadType[i+1])
    dfx <- df3[df3$RoadType == i, ]
    # dfx を 3 つに分割
    dfx1 <- dfx %>% filter(AverageVelocity <= threshold1)
    dfx2 <- dfx %>% filter(AverageVelocity > threshold1, AverageVelocity <= threshold2)
    dfx3 <- dfx %>% filter(AverageVelocity > threshold2)

    for (j in c(1, 2, 3)) {
        # CV 値, 長時間平均, 短時間平均を計算
        if (j == 1) {
            result <- CV(dfx1, verbose=verbose)        
        } else if (j == 2) {
            result <- CV(dfx2, verbose=verbose)        
        } else {
            result <- CV(dfx3, verbose=verbose)        
        }

        printf("Velocity: %s\n", velocities[j])
        printRedRatios(dfx1)        
        printf("Red: Mean correct/predict = %f\n", result[2])
        printf("Blue: Mean correct/predict = %f\n", result[3])
        printf("CV value: %f", result[1])        
        printf("\n\n")
    }
}
# Out:
# RoadType: 5 (主要地方道)
# Velocity: slow
# Red/All = 33/69 = 0.478261
# 1 - Red/All = 36/69 = 0.521739
# Red: Mean correct/predict = 0.399242
# Blue: Mean correct/predict = 0.476623
# CV value: 0.549670
#
# Velocity: middle
# Red/All = 33/69 = 0.478261
# 1 - Red/All = 36/69 = 0.521739
# Red: Mean correct/predict = 0.631472
# Blue: Mean correct/predict = 0.620301
# CV value: 0.376984
#
# Velocity: fast
# Red/All = 33/69 = 0.478261
# 1 - Red/All = 36/69 = 0.521739
# Red: Mean correct/predict = 0.561270
# Blue: Mean correct/predict = 0.366667
# CV value: 0.505152
#
# RoadType: 3 (国道)
# Velocity: slow
# Red/All = 34/52 = 0.653846
# 1 - Red/All = 18/52 = 0.346154
# Red: Mean correct/predict = 0.758889
# Blue: Mean correct/predict = NaN
# CV value: 0.349091
#
# Velocity: middle
# Red/All = 34/52 = 0.653846
# 1 - Red/All = 18/52 = 0.346154
# Red: Mean correct/predict = 0.613833
# Blue: Mean correct/predict = 0.274417
# CV value: 0.484097
#
# Velocity: fast
# Red/All = 34/52 = 0.653846
# 1 - Red/All = 18/52 = 0.346154
# Red: Mean correct/predict = 0.569359
# Blue: Mean correct/predict = 0.396667
# CV value: 0.496047

# %% [markdown]
# # Plot Tree

# %%
# 木を表示
set.seed(1)

# %%
threshold1 <- 10
threshold2 <- 30

# %%
for (i in c(5, 3)) {
    printf("RoadType: %d (%s)\n", i, jRoadType[i+1])
    dfx <- df3[df3$RoadType == i, ]
    dfx1 <- dfx %>% filter(AverageVelocity <= threshold1)
    dfx2 <- dfx %>% filter(AverageVelocity > threshold1, AverageVelocity <= threshold2)
    dfx3 <- dfx %>% filter(AverageVelocity > threshold2)
    
    for (j in c(1, 2, 3)) {
        if (j == 1) {
            fit <- rpart(flag ~ ., data=dfx1, method="class", cp=0.022)
        } else if (j == 2) {
            fit <- rpart(flag ~ ., data=dfx2, method="class", cp=0.022)
        } else {
            fit <- rpart(flag ~ ., data=dfx3, method="class", cp=0.022)
        }
        
        fname = paste("Dtree-RoadType-", velocities[j], "-Velocity-", j, ".png", sep="")
        png(fname, height=960, width=960, res=144)
        plot(fit, uniform=TRUE, main="Classification Tree")
        text(fit, use.n=TRUE, all=TRUE, cex=.6)
        dev.off()
    }
}
# Out:
# RoadType: 5 (主要地方道)
# RoadType: 3 (国道)

# %% [markdown]
# # Importance

# %%
# さらに平均速度で分割したときの Tree の Variable Importance を表示
for (i in c(5, 3)) {
    printf("RoadType: %d (%s)\n", i, jRoadType[i+1])
    dfx <- df3[df3$RoadType == i, ]
    dfx1 <- dfx %>% filter(AverageVelocity <= threshold1)
    dfx2 <- dfx %>% filter(AverageVelocity > threshold1, AverageVelocity <= threshold2)
    dfx3 <- dfx %>% filter(AverageVelocity > threshold2)
    
    for (j in c(1, 2, 3)) {
        if (j == 1) {
            fit <- rpart(flag ~ ., data=dfx1, method="class", cp=0.022)
        } else if (j == 2) {
            fit <- rpart(flag ~ ., data=dfx2, method="class", cp=0.022)
        } else {
            fit <- rpart(flag ~ ., data=dfx3, method="class", cp=0.022)
        }
        summary(fit)
    }
}
# Out:
# RoadType: 5 (主要地方道)
# Call:
# rpart(formula = flag ~ ., data = dfx1, method = "class", cp = 0.022)
#   n= 69
#
#           CP nsplit rel error   xerror      xstd
# 1 0.24242424      0 1.0000000 1.121212 0.1255271
# 2 0.12121212      1 0.7575758 1.090909 0.1257389
# 3 0.03030303      3 0.5151515 1.060606 0.1258447
# 4 0.02200000      4 0.4848485 0.969697 0.1255271
#
# Variable importance
#        DistSignal       TimeHeadway      CurveAverage          Curve100
#                16                14                10                 7
#             Curve   EmptinessOfRoad             Pitch             Speed
#                 7                 6                 6                 5
#     AheadDistance          MaxSpeed     SteeringAngle      DiffAvgSpeed
#                 5                 4                 4                 4
#         LaneCount            Engine   AverageVelocity AccelerationSpeed
#                 3                 3                 3                 2
#
# Node number 1: 69 observations,    complexity param=0.2424242
#   predicted class=Blue  expected loss=0.4782609  P(node) =1
#     class counts:    36    33
#    probabilities: 0.522 0.478
#   left son=2 (13 obs) right son=3 (56 obs)
#   Primary splits:
#       DistSignal    < 185.6171    to the right, improve=5.160057, (0 missing)
#       CurveAverage  < 237.5       to the right, improve=4.695652, (0 missing)
#       TimeHeadway   < 2.856156    to the right, improve=4.159272, (0 missing)
#       SteeringAngle < 5.3         to the left,  improve=3.968116, (0 missing)
#       RiskFactor    < 0.6333064   to the left,  improve=2.712255, (0 missing)
#   Surrogate splits:
#       AverageVelocity < 9.329021    to the right, agree=0.841, adj=0.154, (0 split)
#       Curve100        < 171         to the left,  agree=0.826, adj=0.077, (0 split)
#
# Node number 2: 13 observations
#   predicted class=Blue  expected loss=0.07692308  P(node) =0.1884058
#     class counts:    12     1
#    probabilities: 0.923 0.077
#
# Node number 3: 56 observations,    complexity param=0.1212121
#   predicted class=Red   expected loss=0.4285714  P(node) =0.8115942
#     class counts:    24    32
#    probabilities: 0.429 0.571
#   left son=6 (36 obs) right son=7 (20 obs)
#   Primary splits:
#       CurveAverage    < 237.5       to the right, improve=3.250794, (0 missing)
#       SteeringAngle   < 5.3         to the left,  improve=3.047619, (0 missing)
#       MaxSpeed        < 28.355      to the left,  improve=2.678571, (0 missing)
#       TimeHeadway     < 2.856156    to the right, improve=2.258981, (0 missing)
#       AverageVelocity < 7.397408    to the left,  improve=1.324815, (0 missing)
#   Surrogate splits:
#       Curve           < 244.5       to the right, agree=0.875, adj=0.65, (0 split)
#       Curve100        < 248         to the right, agree=0.857, adj=0.60, (0 split)
#       EmptinessOfRoad < 0.3216839   to the left,  agree=0.857, adj=0.60, (0 split)
#       AheadDistance   < 43.85       to the left,  agree=0.821, adj=0.50, (0 split)
#       SteeringAngle   < 6.05        to the left,  agree=0.786, adj=0.40, (0 split)
#
# Node number 6: 36 observations,    complexity param=0.1212121
#   predicted class=Blue  expected loss=0.4444444  P(node) =0.5217391
#     class counts:    20    16
#    probabilities: 0.556 0.444
#   left son=12 (26 obs) right son=13 (10 obs)
#   Primary splits:
#       TimeHeadway       < 2.856156    to the right, improve=1.808547, (0 missing)
#       MaxSpeed          < 28.355      to the left,  improve=1.777778, (0 missing)
#       TimeToCollision   < 21.91758    to the left,  improve=1.654701, (0 missing)
#       AccelerationSpeed < 0.3         to the left,  improve=1.265463, (0 missing)
#       Engine            < 1303.125    to the right, improve=1.002778, (0 missing)
#   Surrogate splits:
#       LaneCount         < 2.5         to the left,  agree=0.861, adj=0.5, (0 split)
#       MaxSpeed          < 28.355      to the left,  agree=0.833, adj=0.4, (0 split)
#       Pitch             < 0.02587065  to the left,  agree=0.833, adj=0.4, (0 split)
#       AccelerationSpeed < -0.1583333  to the right, agree=0.833, adj=0.4, (0 split)
#       Speed             < 20.645      to the left,  agree=0.806, adj=0.3, (0 split)
#
# Node number 7: 20 observations
#   predicted class=Red   expected loss=0.2  P(node) =0.2898551
#     class counts:     4    16
#    probabilities: 0.200 0.800
#
# Node number 12: 26 observations,    complexity param=0.03030303
#   predicted class=Blue  expected loss=0.3461538  P(node) =0.3768116
#     class counts:    17     9
#    probabilities: 0.654 0.346
#   left son=24 (11 obs) right son=25 (15 obs)
#   Primary splits:
#       TimeHeadway       < 3.652433    to the left,  improve=2.484382, (0 missing)
#       RiskFactor        < 0.4294108   to the right, improve=2.295547, (0 missing)
#       TimeToCollision   < 21.91758    to the left,  improve=2.295547, (0 missing)
#       AccelerationSpeed < 0.09444444  to the left,  improve=1.969231, (0 missing)
#       Pitch             < 0.002736318 to the left,  improve=1.514685, (0 missing)
#   Surrogate splits:
#       Speed        < 14.905      to the right, agree=0.769, adj=0.455, (0 split)
#       Pitch        < -0.01119403 to the left,  agree=0.769, adj=0.455, (0 split)
#       DiffAvgSpeed < -3.313956   to the right, agree=0.769, adj=0.455, (0 split)
#       Engine       < 1448.438    to the right, agree=0.731, adj=0.364, (0 split)
#       MaxSpeed     < 25.545      to the right, agree=0.692, adj=0.273, (0 split)
#
# Node number 13: 10 observations
#   predicted class=Red   expected loss=0.3  P(node) =0.1449275
#     class counts:     3     7
#    probabilities: 0.300 0.700
#
# Node number 24: 11 observations
#   predicted class=Blue  expected loss=0.09090909  P(node) =0.1594203
#     class counts:    10     1
#    probabilities: 0.909 0.091
#
# Node number 25: 15 observations
#   predicted class=Red   expected loss=0.4666667  P(node) =0.2173913
#     class counts:     7     8
#    probabilities: 0.467 0.533
#
# Call:
# rpart(formula = flag ~ ., data = dfx2, method = "class", cp = 0.022)
#   n= 178
#
#           CP nsplit rel error    xerror       xstd
# 1 0.30337079      0 1.0000000 1.1123596 0.07447854
# 2 0.07865169      1 0.6966292 0.8876404 0.07447854
# 3 0.03370787      3 0.5393258 0.7865169 0.07322525
# 4 0.02247191      4 0.5056180 0.7977528 0.07340422
# 5 0.02200000      8 0.4044944 0.8539326 0.07414927
#
# Variable importance
#        RiskFactor       TimeHeadway             Speed AccelerationSpeed
#                12                11                11                 9
#            Engine     SteeringAngle      DiffAvgSpeed          Curve150
#                 8                 7                 7                 6
#   TimeToCollision     AheadDistance          MaxSpeed      CurveAverage
#                 5                 5                 4                 4
#   AverageVelocity          Curve100             Curve              Jerk
#                 4                 3                 3                 1
#
# Node number 1: 178 observations,    complexity param=0.3033708
#   predicted class=Blue  expected loss=0.5  P(node) =1
#     class counts:    89    89
#    probabilities: 0.500 0.500
#   left son=2 (103 obs) right son=3 (75 obs)
#   Primary splits:
#       TimeHeadway       < 2.54646     to the right, improve=8.398835, (0 missing)
#       RiskFactor        < 0.4613778   to the left,  improve=7.619554, (0 missing)
#       Engine            < 1573.438    to the left,  improve=6.628600, (0 missing)
#       Speed             < 49.365      to the left,  improve=5.862275, (0 missing)
#       AccelerationSpeed < 0.575       to the left,  improve=5.297619, (0 missing)
#   Surrogate splits:
#       RiskFactor      < 0.4613778   to the left,  agree=0.860, adj=0.667, (0 split)
#       AheadDistance   < 23.65       to the right, agree=0.702, adj=0.293, (0 split)
#       TimeToCollision < 20.88908    to the right, agree=0.674, adj=0.227, (0 split)
#       SteeringAngle   < -1.2        to the right, agree=0.646, adj=0.160, (0 split)
#       Curve150        < 247.5       to the right, agree=0.624, adj=0.107, (0 split)
#
# Node number 2: 103 observations,    complexity param=0.07865169
#   predicted class=Blue  expected loss=0.368932  P(node) =0.5786517
#     class counts:    65    38
#    probabilities: 0.631 0.369
#   left son=4 (96 obs) right son=5 (7 obs)
#   Primary splits:
#       Speed             < 49.365      to the left,  improve=5.981998, (0 missing)
#       AccelerationSpeed < 0.5694444   to the left,  improve=5.981998, (0 missing)
#       DiffAvgSpeed      < 28.99866    to the left,  improve=4.442744, (0 missing)
#       Engine            < 1645.312    to the left,  improve=3.580213, (0 missing)
#       SteeringAngle     < 15.05       to the left,  improve=3.580213, (0 missing)
#   Surrogate splits:
#       DiffAvgSpeed < 35.09122    to the left,  agree=0.981, adj=0.714, (0 split)
#       MaxSpeed     < 51.31       to the left,  agree=0.961, adj=0.429, (0 split)
#
# Node number 3: 75 observations,    complexity param=0.02247191
#   predicted class=Red   expected loss=0.32  P(node) =0.4213483
#     class counts:    24    51
#    probabilities: 0.320 0.680
#   left son=6 (64 obs) right son=7 (11 obs)
#   Primary splits:
#       Engine   < 1556.25     to the left,  improve=2.640000, (0 missing)
#       Jerk     < 0.25        to the left,  improve=2.469942, (0 missing)
#       Curve150 < 144         to the left,  improve=2.458182, (0 missing)
#       MaxSpeed < 42.64       to the left,  improve=1.846259, (0 missing)
#       Curve    < 161         to the right, improve=1.834030, (0 missing)
#   Surrogate splits:
#       Jerk              < 4           to the left,  agree=0.893, adj=0.273, (0 split)
#       AccelerationSpeed < 0.3222222   to the left,  agree=0.880, adj=0.182, (0 split)
#
# Node number 4: 96 observations,    complexity param=0.07865169
#   predicted class=Blue  expected loss=0.3229167  P(node) =0.5393258
#     class counts:    65    31
#    probabilities: 0.677 0.323
#   left son=8 (89 obs) right son=9 (7 obs)
#   Primary splits:
#       AccelerationSpeed < 0.5694444   to the left,  improve=6.922987, (0 missing)
#       Engine            < 1645.312    to the left,  improve=4.309825, (0 missing)
#       SteeringAngle     < 15.05       to the left,  improve=4.309825, (0 missing)
#       Speed             < 32.135      to the right, improve=3.881034, (0 missing)
#       DiffAvgSpeed      < 10.63366    to the right, improve=3.500735, (0 missing)
#   Surrogate splits:
#       SteeringAngle < 18.05       to the left,  agree=0.969, adj=0.571, (0 split)
#       Engine        < 1775        to the left,  agree=0.958, adj=0.429, (0 split)
#       Speed         < 5.76        to the right, agree=0.948, adj=0.286, (0 split)
#       AheadDistance < 7.4         to the right, agree=0.938, adj=0.143, (0 split)
#       DiffAvgSpeed  < -13.10853   to the right, agree=0.938, adj=0.143, (0 split)
#
# Node number 5: 7 observations
#   predicted class=Red   expected loss=0  P(node) =0.03932584
#     class counts:     0     7
#    probabilities: 0.000 1.000
#
# Node number 6: 64 observations,    complexity param=0.02247191
#   predicted class=Red   expected loss=0.375  P(node) =0.3595506
#     class counts:    24    40
#    probabilities: 0.375 0.625
#   left son=12 (8 obs) right son=13 (56 obs)
#   Primary splits:
#       Curve150          < 144         to the left,  improve=2.571429, (0 missing)
#       Jerk              < -0.4166667  to the left,  improve=2.571429, (0 missing)
#       AverageVelocity   < 24.46635    to the right, improve=2.512821, (0 missing)
#       Engine            < 1414.062    to the right, improve=2.512821, (0 missing)
#       AccelerationSpeed < 0.2361111   to the right, improve=1.809524, (0 missing)
#   Surrogate splits:
#       Curve100   < 85.5        to the left,  agree=0.906, adj=0.250, (0 split)
#       RoadFactor < 3.5         to the right, agree=0.891, adj=0.125, (0 split)
#
# Node number 7: 11 observations
#   predicted class=Red   expected loss=0  P(node) =0.06179775
#     class counts:     0    11
#    probabilities: 0.000 1.000
#
# Node number 8: 89 observations,    complexity param=0.03370787
#   predicted class=Blue  expected loss=0.2696629  P(node) =0.5
#     class counts:    65    24
#    probabilities: 0.730 0.270
#   left son=16 (80 obs) right son=17 (9 obs)
#   Primary splits:
#       RiskFactor      < 0.534926    to the left,  improve=3.156180, (0 missing)
#       Pitch           < -0.01293532 to the left,  improve=2.837002, (0 missing)
#       TimeToCollision < 26.11133    to the right, improve=2.835592, (0 missing)
#       TimeHeadway     < 3.889267    to the right, improve=2.542811, (0 missing)
#       DistSignal      < 67.27647    to the right, improve=2.017430, (0 missing)
#   Surrogate splits:
#       TimeToCollision < 21.09294    to the right, agree=0.978, adj=0.778, (0 split)
#       CurveAverage    < 253         to the left,  agree=0.921, adj=0.222, (0 split)
#       Curve100        < 253         to the left,  agree=0.921, adj=0.222, (0 split)
#       Curve150        < 253         to the left,  agree=0.921, adj=0.222, (0 split)
#       Curve           < 253         to the left,  agree=0.921, adj=0.222, (0 split)
#
# Node number 9: 7 observations
#   predicted class=Red   expected loss=0  P(node) =0.03932584
#     class counts:     0     7
#    probabilities: 0.000 1.000
#
# Node number 12: 8 observations
#   predicted class=Blue  expected loss=0.25  P(node) =0.04494382
#     class counts:     6     2
#    probabilities: 0.750 0.250
#
# Node number 13: 56 observations,    complexity param=0.02247191
#   predicted class=Red   expected loss=0.3214286  P(node) =0.3146067
#     class counts:    18    38
#    probabilities: 0.321 0.679
#   left son=26 (34 obs) right son=27 (22 obs)
#   Primary splits:
#       CurveAverage      < 249.5       to the right, improve=2.482047, (0 missing)
#       AccelerationSpeed < 0.2361111   to the right, improve=2.469388, (0 missing)
#       Jerk              < -0.4166667  to the left,  improve=2.469388, (0 missing)
#       Curve150          < 247.5       to the right, improve=2.215805, (0 missing)
#       Engine            < 1262.5      to the right, improve=1.935596, (0 missing)
#   Surrogate splits:
#       Curve         < 249.5       to the right, agree=0.857, adj=0.636, (0 split)
#       Curve100      < 243.5       to the right, agree=0.768, adj=0.409, (0 split)
#       AheadDistance < 14.4        to the right, agree=0.714, adj=0.273, (0 split)
#       Speed         < 19.995      to the right, agree=0.696, adj=0.227, (0 split)
#       Curve150      < 247.5       to the right, agree=0.696, adj=0.227, (0 split)
#
# Node number 16: 80 observations
#   predicted class=Blue  expected loss=0.225  P(node) =0.4494382
#     class counts:    62    18
#    probabilities: 0.775 0.225
#
# Node number 17: 9 observations
#   predicted class=Red   expected loss=0.3333333  P(node) =0.0505618
#     class counts:     3     6
#    probabilities: 0.333 0.667
#
# Node number 26: 34 observations,    complexity param=0.02247191
#   predicted class=Red   expected loss=0.4411765  P(node) =0.1910112
#     class counts:    15    19
#    probabilities: 0.441 0.559
#   left son=52 (7 obs) right son=53 (27 obs)
#   Primary splits:
#       AverageVelocity < 24.46635    to the right, improve=3.050420, (0 missing)
#       Jerk            < 0.25        to the left,  improve=2.882353, (0 missing)
#       Pitch           < 0.06144279  to the right, improve=1.995475, (0 missing)
#       TimeToCollision < 46.06612    to the left,  improve=1.634881, (0 missing)
#       Engine          < 1262.5      to the right, improve=1.634881, (0 missing)
#   Surrogate splits:
#       MaxSpeed    < 46.76       to the right, agree=0.853, adj=0.286, (0 split)
#       RiskFactor  < 0.4303683   to the left,  agree=0.853, adj=0.286, (0 split)
#       Engine      < 1442.188    to the right, agree=0.853, adj=0.286, (0 split)
#       TimeHeadway < 2.45323     to the right, agree=0.853, adj=0.286, (0 split)
#       Jerk        < -0.7777778  to the left,  agree=0.824, adj=0.143, (0 split)
#
# Node number 27: 22 observations
#   predicted class=Red   expected loss=0.1363636  P(node) =0.1235955
#     class counts:     3    19
#    probabilities: 0.136 0.864
#
# Node number 52: 7 observations
#   predicted class=Blue  expected loss=0.1428571  P(node) =0.03932584
#     class counts:     6     1
#    probabilities: 0.857 0.143
#
# Node number 53: 27 observations
#   predicted class=Red   expected loss=0.3333333  P(node) =0.1516854
#     class counts:     9    18
#    probabilities: 0.333 0.667
#
# Call:
# rpart(formula = flag ~ ., data = dfx3, method = "class", cp = 0.022)
#   n= 56
#
#           CP nsplit rel error xerror      xstd
# 1 0.33333333      0 1.0000000  1.000 0.1543033
# 2 0.16666667      1 0.6666667  1.125 0.1558029
# 3 0.08333333      2 0.5000000  1.250 0.1555042
# 4 0.02200000      3 0.4166667  1.250 0.1555042
#
# Variable importance
#        RiskFactor       TimeHeadway          Curve100 AccelerationSpeed
#                16                14                13                11
#     AheadDistance      CurveAverage   EmptinessOfRoad             Pitch
#                11                 9                 6                 6
#             Curve          Curve150   TimeToCollision             Speed
#                 4                 3                 3                 2
#   AverageVelocity        RoadFactor
#                 1                 1
#
# Node number 1: 56 observations,    complexity param=0.3333333
#   predicted class=Red   expected loss=0.4285714  P(node) =1
#     class counts:    24    32
#    probabilities: 0.429 0.571
#   left son=2 (14 obs) right son=3 (42 obs)
#   Primary splits:
#       RiskFactor    < 0.3114708  to the left,  improve=4.761905, (0 missing)
#       TimeHeadway   < 3.564625   to the right, improve=4.761905, (0 missing)
#       LaneCount     < 2.5        to the left,  improve=4.128571, (0 missing)
#       Curve100      < 224        to the left,  improve=3.929466, (0 missing)
#       AheadDistance < 47.05      to the right, improve=3.809524, (0 missing)
#   Surrogate splits:
#       TimeHeadway     < 3.564625   to the right, agree=1.000, adj=1.000, (0 split)
#       AheadDistance   < 57.95      to the right, agree=0.911, adj=0.643, (0 split)
#       EmptinessOfRoad < 0.3938528  to the right, agree=0.857, adj=0.429, (0 split)
#       Curve           < 227.5      to the left,  agree=0.821, adj=0.286, (0 split)
#       Speed           < 57.715     to the right, agree=0.786, adj=0.143, (0 split)
#
# Node number 2: 14 observations
#   predicted class=Blue  expected loss=0.2142857  P(node) =0.25
#     class counts:    11     3
#    probabilities: 0.786 0.214
#
# Node number 3: 42 observations,    complexity param=0.1666667
#   predicted class=Red   expected loss=0.3095238  P(node) =0.75
#     class counts:    13    29
#    probabilities: 0.310 0.690
#   left son=6 (8 obs) right son=7 (34 obs)
#   Primary splits:
#       Curve100          < 224        to the left,  improve=3.834734, (0 missing)
#       LaneCount         < 2.5        to the left,  improve=3.219048, (0 missing)
#       CurveAverage      < 246.5      to the left,  improve=2.337566, (0 missing)
#       AccelerationSpeed < -0.1555556 to the left,  improve=1.967087, (0 missing)
#       MaxSpeed          < 58.66      to the left,  improve=1.943290, (0 missing)
#   Surrogate splits:
#       CurveAverage    < 203.5      to the left,  agree=0.952, adj=0.750, (0 split)
#       Curve150        < 170.5      to the left,  agree=0.857, adj=0.250, (0 split)
#       Pitch           < -0.185199  to the left,  agree=0.857, adj=0.250, (0 split)
#       AverageVelocity < 54.37841   to the right, agree=0.833, adj=0.125, (0 split)
#       RoadFactor      < 2.5        to the right, agree=0.833, adj=0.125, (0 split)
#
# Node number 6: 8 observations
#   predicted class=Blue  expected loss=0.25  P(node) =0.1428571
#     class counts:     6     2
#    probabilities: 0.750 0.250
#
# Node number 7: 34 observations,    complexity param=0.08333333
#   predicted class=Red   expected loss=0.2058824  P(node) =0.6071429
#     class counts:     7    27
#    probabilities: 0.206 0.794
#   left son=14 (8 obs) right son=15 (26 obs)
#   Primary splits:
#       AccelerationSpeed < -0.1472222 to the left,  improve=3.675339, (0 missing)
#       DistSignal        < 137.5915   to the right, improve=2.450980, (0 missing)
#       Jerk              < 0.7222222  to the right, improve=2.450980, (0 missing)
#       Pitch             < 0.03146766 to the right, improve=2.355742, (0 missing)
#       TimeToCollision   < 90.314     to the left,  improve=1.784314, (0 missing)
#   Surrogate splits:
#       Pitch           < 0.0420398  to the right, agree=0.824, adj=0.250, (0 split)
#       TimeToCollision < 15.14077   to the left,  agree=0.824, adj=0.250, (0 split)
#       Curve100        < 246.5      to the left,  agree=0.794, adj=0.125, (0 split)
#       RiskFactor      < 1.401754   to the right, agree=0.794, adj=0.125, (0 split)
#       AheadDistance   < 71.85      to the right, agree=0.794, adj=0.125, (0 split)
#
# Node number 14: 8 observations
#   predicted class=Blue  expected loss=0.375  P(node) =0.1428571
#     class counts:     5     3
#    probabilities: 0.625 0.375
#
# Node number 15: 26 observations
#   predicted class=Red   expected loss=0.07692308  P(node) =0.4642857
#     class counts:     2    24
#    probabilities: 0.077 0.923
#
# RoadType: 3 (国道)
# Call:
# rpart(formula = flag ~ ., data = dfx1, method = "class", cp = 0.022)
#   n= 52
#
#          CP nsplit rel error    xerror      xstd
# 1 0.3888889      0 1.0000000 1.0000000 0.1905906
# 2 0.0220000      1 0.6111111 0.6666667 0.1687899
#
# Variable importance
# AheadDistance  DiffAvgSpeed         Speed      MaxSpeed      Curve100
#            50            18            14             9             5
#      Curve150
#             5
#
# Node number 1: 52 observations,    complexity param=0.3888889
#   predicted class=Red   expected loss=0.3461538  P(node) =1
#     class counts:    18    34
#    probabilities: 0.346 0.654
#   left son=2 (11 obs) right son=3 (41 obs)
#   Primary splits:
#       AheadDistance   < 15.9      to the right, improve=6.216954, (0 missing)
#       MaxSpeed        < 33.665    to the right, improve=4.224176, (0 missing)
#       TimeHeadway     < 2.625522  to the right, improve=2.960310, (0 missing)
#       RiskFactor      < 0.7016003 to the left,  improve=2.512821, (0 missing)
#       TimeToCollision < 15.73611  to the right, improve=2.265734, (0 missing)
#   Surrogate splits:
#       DiffAvgSpeed < 10.00873  to the right, agree=0.865, adj=0.364, (0 split)
#       Speed        < 38.465    to the right, agree=0.846, adj=0.273, (0 split)
#       MaxSpeed     < 32.805    to the right, agree=0.827, adj=0.182, (0 split)
#       Curve100     < 125       to the left,  agree=0.808, adj=0.091, (0 split)
#       Curve150     < 121.5     to the left,  agree=0.808, adj=0.091, (0 split)
#
# Node number 2: 11 observations
#   predicted class=Blue  expected loss=0.1818182  P(node) =0.2115385
#     class counts:     9     2
#    probabilities: 0.818 0.182
#
# Node number 3: 41 observations
#   predicted class=Red   expected loss=0.2195122  P(node) =0.7884615
#     class counts:     9    32
#    probabilities: 0.220 0.780
#
# Call:
# rpart(formula = flag ~ ., data = dfx2, method = "class", cp = 0.022)
#   n= 161
#
#           CP nsplit rel error   xerror      xstd
# 1 0.12068966      0 1.0000000 1.000000 0.1050248
# 2 0.10344828      2 0.7586207 1.137931 0.1075952
# 3 0.03448276      3 0.6551724 1.017241 0.1054108
# 4 0.02200000      8 0.4827586 1.120690 0.1073375
#
# Variable importance
#           Pitch          Engine        MaxSpeed           Speed    DiffAvgSpeed
#              16              13              10              10               8
#   SteeringAngle    CurveAverage        Curve100 TimeToCollision      DistSignal
#               6               6               6               5               4
#      RiskFactor AverageVelocity           Curve   AheadDistance        Curve150
#               4               3               3               2               1
#     TimeHeadway EmptinessOfRoad
#               1               1
#
# Node number 1: 161 observations,    complexity param=0.1206897
#   predicted class=Red   expected loss=0.3602484  P(node) =1
#     class counts:    58   103
#    probabilities: 0.360 0.640
#   left son=2 (53 obs) right son=3 (108 obs)
#   Primary splits:
#       Pitch           < -0.04900498 to the left,  improve=6.691963, (0 missing)
#       AverageVelocity < 13.73089    to the left,  improve=4.132233, (0 missing)
#       DistSignal      < 281.1769    to the right, improve=3.613778, (0 missing)
#       CurveAverage    < 179.5       to the right, improve=3.325069, (0 missing)
#       TimeHeadway     < 4.227402    to the right, improve=3.312629, (0 missing)
#   Surrogate splits:
#       DiffAvgSpeed    < 33.08078    to the right, agree=0.720, adj=0.151, (0 split)
#       Speed           < 52.135      to the right, agree=0.708, adj=0.113, (0 split)
#       DistSignal      < 226.5808    to the right, agree=0.702, adj=0.094, (0 split)
#       EmptinessOfRoad < 0.2586756   to the right, agree=0.689, adj=0.057, (0 split)
#       AverageVelocity < 10.59498    to the left,  agree=0.683, adj=0.038, (0 split)
#
# Node number 2: 53 observations,    complexity param=0.1206897
#   predicted class=Blue  expected loss=0.4339623  P(node) =0.3291925
#     class counts:    30    23
#    probabilities: 0.566 0.434
#   left son=4 (24 obs) right son=5 (29 obs)
#   Primary splits:
#       Pitch    < -0.1251244  to the right, improve=4.465897, (0 missing)
#       MaxSpeed < 54.14       to the left,  improve=3.869620, (0 missing)
#       Engine   < 1417.188    to the left,  improve=3.766903, (0 missing)
#       Speed    < 52.85       to the left,  improve=3.701135, (0 missing)
#       Curve100 < 249         to the right, improve=3.359673, (0 missing)
#   Surrogate splits:
#       MaxSpeed        < 55.22       to the left,  agree=0.717, adj=0.375, (0 split)
#       TimeToCollision < 21.32323    to the left,  agree=0.679, adj=0.292, (0 split)
#       SteeringAngle   < 6.85        to the right, agree=0.679, adj=0.292, (0 split)
#       Speed           < 52.85       to the left,  agree=0.660, adj=0.250, (0 split)
#       Curve100        < 249         to the right, agree=0.642, adj=0.208, (0 split)
#
# Node number 3: 108 observations,    complexity param=0.03448276
#   predicted class=Red   expected loss=0.2592593  P(node) =0.6708075
#     class counts:    28    80
#    probabilities: 0.259 0.741
#   left son=6 (53 obs) right son=7 (55 obs)
#   Primary splits:
#       CurveAverage    < 179.5       to the right, improve=2.903094, (0 missing)
#       Curve           < 199         to the right, improve=2.469136, (0 missing)
#       RiskFactor      < 0.4296344   to the left,  improve=2.445767, (0 missing)
#       EmptinessOfRoad < 0.247239    to the right, improve=2.311481, (0 missing)
#       AverageVelocity < 13.21331    to the left,  improve=2.304154, (0 missing)
#   Surrogate splits:
#       Curve           < 215         to the right, agree=0.750, adj=0.491, (0 split)
#       Curve100        < 248.5       to the right, agree=0.722, adj=0.434, (0 split)
#       Curve150        < 187.5       to the right, agree=0.648, adj=0.283, (0 split)
#       MaxSpeed        < 53.285      to the left,  agree=0.639, adj=0.264, (0 split)
#       AverageVelocity < 22.53821    to the left,  agree=0.639, adj=0.264, (0 split)
#
# Node number 4: 24 observations
#   predicted class=Blue  expected loss=0.2083333  P(node) =0.1490683
#     class counts:    19     5
#    probabilities: 0.792 0.208
#
# Node number 5: 29 observations,    complexity param=0.1034483
#   predicted class=Red   expected loss=0.3793103  P(node) =0.1801242
#     class counts:    11    18
#    probabilities: 0.379 0.621
#   left son=10 (12 obs) right son=11 (17 obs)
#   Primary splits:
#       Engine          < 1348.438    to the left,  improve=5.625761, (0 missing)
#       TimeToCollision < 43.94854    to the right, improve=4.392015, (0 missing)
#       Speed           < 38.52       to the left,  improve=4.291536, (0 missing)
#       DiffAvgSpeed    < 13.15101    to the left,  improve=3.139383, (0 missing)
#       DistSignal      < 189.4623    to the right, improve=3.036125, (0 missing)
#   Surrogate splits:
#       Speed        < 36          to the left,  agree=0.828, adj=0.583, (0 split)
#       DiffAvgSpeed < 12.96601    to the left,  agree=0.793, adj=0.500, (0 split)
#       DistSignal   < 278.0899    to the right, agree=0.724, adj=0.333, (0 split)
#       CurveAverage < 223         to the right, agree=0.690, adj=0.250, (0 split)
#       Curve100     < 249         to the right, agree=0.690, adj=0.250, (0 split)
#
# Node number 6: 53 observations,    complexity param=0.03448276
#   predicted class=Red   expected loss=0.3773585  P(node) =0.3291925
#     class counts:    20    33
#    probabilities: 0.377 0.623
#   left son=12 (44 obs) right son=13 (9 obs)
#   Primary splits:
#       SteeringAngle   < -0.6        to the right, improve=3.087479, (0 missing)
#       AheadDistance   < 15.75       to the right, improve=2.876335, (0 missing)
#       AverageVelocity < 12.85498    to the left,  improve=2.616771, (0 missing)
#       Engine          < 1446.875    to the right, improve=2.596717, (0 missing)
#       Speed           < 28.14       to the right, improve=2.491625, (0 missing)
#   Surrogate splits:
#       RiskFactor      < 1.193212    to the left,  agree=0.868, adj=0.222, (0 split)
#       TimeHeadway     < 1.34706     to the right, agree=0.868, adj=0.222, (0 split)
#       Curve           < 221.5       to the right, agree=0.849, adj=0.111, (0 split)
#       DistSignal      < 241.9782    to the left,  agree=0.849, adj=0.111, (0 split)
#       TimeToCollision < 11.34811    to the right, agree=0.849, adj=0.111, (0 split)
#
# Node number 7: 55 observations
#   predicted class=Red   expected loss=0.1454545  P(node) =0.3416149
#     class counts:     8    47
#    probabilities: 0.145 0.855
#
# Node number 10: 12 observations
#   predicted class=Blue  expected loss=0.25  P(node) =0.07453416
#     class counts:     9     3
#    probabilities: 0.750 0.250
#
# Node number 11: 17 observations
#   predicted class=Red   expected loss=0.1176471  P(node) =0.1055901
#     class counts:     2    15
#    probabilities: 0.118 0.882
#
# Node number 12: 44 observations,    complexity param=0.03448276
#   predicted class=Red   expected loss=0.4545455  P(node) =0.2732919
#     class counts:    20    24
#    probabilities: 0.455 0.545
#   left son=24 (10 obs) right son=25 (34 obs)
#   Primary splits:
#       Engine          < 1445.312    to the right, improve=3.088770, (0 missing)
#       Speed           < 27.84       to the right, improve=2.734848, (0 missing)
#       AheadDistance   < 15.75       to the right, improve=2.663498, (0 missing)
#       DiffAvgSpeed    < 11.92344    to the right, improve=2.174289, (0 missing)
#       EmptinessOfRoad < 0.1930063   to the right, improve=2.086172, (0 missing)
#   Surrogate splits:
#       Curve100        < 245         to the left,  agree=0.818, adj=0.2, (0 split)
#       MaxSpeed        < 56.64       to the right, agree=0.818, adj=0.2, (0 split)
#       RiskFactor      < 0.1811142   to the left,  agree=0.818, adj=0.2, (0 split)
#       AheadDistance   < 62.9        to the right, agree=0.818, adj=0.2, (0 split)
#       AverageVelocity < 12.23377    to the left,  agree=0.818, adj=0.2, (0 split)
#
# Node number 13: 9 observations
#   predicted class=Red   expected loss=0  P(node) =0.05590062
#     class counts:     0     9
#    probabilities: 0.000 1.000
#
# Node number 24: 10 observations
#   predicted class=Blue  expected loss=0.2  P(node) =0.0621118
#     class counts:     8     2
#    probabilities: 0.800 0.200
#
# Node number 25: 34 observations,    complexity param=0.03448276
#   predicted class=Red   expected loss=0.3529412  P(node) =0.2111801
#     class counts:    12    22
#    probabilities: 0.353 0.647
#   left son=50 (24 obs) right son=51 (10 obs)
#   Primary splits:
#       MaxSpeed        < 51.75       to the left,  improve=3.529412, (0 missing)
#       DistSignal      < 173.0009    to the right, improve=2.301899, (0 missing)
#       DiffAvgSpeed    < 11.92344    to the right, improve=2.117647, (0 missing)
#       AverageVelocity < 20.21351    to the left,  improve=1.668606, (0 missing)
#       Speed           < 34.67       to the right, improve=1.654412, (0 missing)
#   Surrogate splits:
#       Speed           < 14.89       to the right, agree=0.794, adj=0.3, (0 split)
#       DiffAvgSpeed    < -9.671333   to the right, agree=0.794, adj=0.3, (0 split)
#       RiskFactor      < 0.3687906   to the right, agree=0.765, adj=0.2, (0 split)
#       AverageVelocity < 22.44336    to the left,  agree=0.765, adj=0.2, (0 split)
#       TimeToCollision < 13.9233     to the right, agree=0.765, adj=0.2, (0 split)
#
# Node number 50: 24 observations,    complexity param=0.03448276
#   predicted class=Blue  expected loss=0.5  P(node) =0.1490683
#     class counts:    12    12
#    probabilities: 0.500 0.500
#   left son=100 (14 obs) right son=101 (10 obs)
#   Primary splits:
#       TimeToCollision < 35.33232    to the right, improve=1.371429, (0 missing)
#       DiffAvgSpeed    < 11.92344    to the right, improve=1.371429, (0 missing)
#       MaxSpeed        < 46.49       to the right, improve=1.333333, (0 missing)
#       RiskFactor      < 0.7271226   to the left,  improve=0.907563, (0 missing)
#       DistSignal      < 173.0009    to the right, improve=0.907563, (0 missing)
#   Surrogate splits:
#       Speed         < 29.12       to the right, agree=0.792, adj=0.5, (0 split)
#       DiffAvgSpeed  < 6.218443    to the right, agree=0.792, adj=0.5, (0 split)
#       AheadDistance < 15.3        to the right, agree=0.750, adj=0.4, (0 split)
#       MaxSpeed      < 46.225      to the right, agree=0.708, adj=0.3, (0 split)
#       RiskFactor    < 0.6075905   to the left,  agree=0.708, adj=0.3, (0 split)
#
# Node number 51: 10 observations
#   predicted class=Red   expected loss=0  P(node) =0.0621118
#     class counts:     0    10
#    probabilities: 0.000 1.000
#
# Node number 100: 14 observations
#   predicted class=Blue  expected loss=0.3571429  P(node) =0.08695652
#     class counts:     9     5
#    probabilities: 0.643 0.357
#
# Node number 101: 10 observations
#   predicted class=Red   expected loss=0.3  P(node) =0.0621118
#     class counts:     3     7
#    probabilities: 0.300 0.700
#
# Call:
# rpart(formula = flag ~ ., data = dfx3, method = "class", cp = 0.022)
#   n= 111
#
#           CP nsplit rel error   xerror      xstd
# 1 0.10869565      0 1.0000000 1.000000 0.1128278
# 2 0.05434783      3 0.6304348 1.282609 0.1142900
# 3 0.02200000      5 0.5217391 1.326087 0.1139543
#
# Variable importance
#     AheadDistance      CurveAverage             Pitch          Curve150
#                10                10                10                10
#             Curve          Curve100          MaxSpeed   EmptinessOfRoad
#                 9                 8                 5                 5
#             Speed   AverageVelocity   TimeToCollision       TimeHeadway
#                 5                 4                 4                 4
# AccelerationSpeed        RiskFactor      DiffAvgSpeed     SteeringAngle
#                 4                 4                 3                 3
#            Engine
#                 2
#
# Node number 1: 111 observations,    complexity param=0.1086957
#   predicted class=Red   expected loss=0.4144144  P(node) =1
#     class counts:    46    65
#    probabilities: 0.414 0.586
#   left son=2 (77 obs) right son=3 (34 obs)
#   Primary splits:
#       Curve150        < 223        to the right, improve=4.262720, (0 missing)
#       Jerk            < -1.027778  to the left,  improve=3.981147, (0 missing)
#       Curve100        < 205.5      to the right, improve=3.780047, (0 missing)
#       RiskFactor      < 1.245826   to the right, improve=3.657854, (0 missing)
#       TimeToCollision < 6.03757    to the left,  improve=3.657854, (0 missing)
#   Surrogate splits:
#       Curve100          < 223        to the right, agree=0.865, adj=0.559, (0 split)
#       CurveAverage      < 162.5      to the right, agree=0.838, adj=0.471, (0 split)
#       Speed             < 18.485     to the right, agree=0.730, adj=0.118, (0 split)
#       AccelerationSpeed < 0.1805556  to the left,  agree=0.730, adj=0.118, (0 split)
#       Pitch             < -0.3139303 to the right, agree=0.721, adj=0.088, (0 split)
#
# Node number 2: 77 observations,    complexity param=0.1086957
#   predicted class=Blue  expected loss=0.4935065  P(node) =0.6936937
#     class counts:    39    38
#    probabilities: 0.506 0.494
#   left son=4 (16 obs) right son=5 (61 obs)
#   Primary splits:
#       AheadDistance   < 41.5       to the right, improve=3.782441, (0 missing)
#       RiskFactor      < 1.245826   to the right, improve=3.750649, (0 missing)
#       TimeToCollision < 6.03757    to the left,  improve=3.750649, (0 missing)
#       AverageVelocity < 34.09218   to the left,  improve=3.209636, (0 missing)
#       Engine          < 1418.75    to the right, improve=2.909193, (0 missing)
#   Surrogate splits:
#       TimeHeadway     < 2.827055   to the right, agree=0.896, adj=0.500, (0 split)
#       RiskFactor      < 0.3699253  to the left,  agree=0.883, adj=0.437, (0 split)
#       EmptinessOfRoad < 0.247239   to the right, agree=0.870, adj=0.375, (0 split)
#       TimeToCollision < 6.03757    to the left,  agree=0.857, adj=0.312, (0 split)
#       Curve100        < 193.5      to the left,  agree=0.844, adj=0.250, (0 split)
#
# Node number 3: 34 observations
#   predicted class=Red   expected loss=0.2058824  P(node) =0.3063063
#     class counts:     7    27
#    probabilities: 0.206 0.794
#
# Node number 4: 16 observations
#   predicted class=Blue  expected loss=0.1875  P(node) =0.1441441
#     class counts:    13     3
#    probabilities: 0.812 0.188
#
# Node number 5: 61 observations,    complexity param=0.1086957
#   predicted class=Red   expected loss=0.4262295  P(node) =0.5495495
#     class counts:    26    35
#    probabilities: 0.426 0.574
#   left son=10 (11 obs) right son=11 (50 obs)
#   Primary splits:
#       Curve         < 225.5      to the left,  improve=4.123338, (0 missing)
#       CurveAverage  < 248.5      to the left,  improve=3.686333, (0 missing)
#       Pitch         < 0.07064677 to the right, improve=3.126606, (0 missing)
#       SteeringAngle < 2.35       to the left,  improve=2.327294, (0 missing)
#       Engine        < 1379.688   to the right, improve=2.298632, (0 missing)
#   Surrogate splits:
#       CurveAverage  < 154.5      to the left,  agree=0.934, adj=0.636, (0 split)
#       Pitch         < 0.4919154  to the right, agree=0.869, adj=0.273, (0 split)
#       SteeringAngle < -0.4       to the left,  agree=0.869, adj=0.273, (0 split)
#       MaxSpeed      < 48.87      to the left,  agree=0.852, adj=0.182, (0 split)
#
# Node number 10: 11 observations
#   predicted class=Blue  expected loss=0.1818182  P(node) =0.0990991
#     class counts:     9     2
#    probabilities: 0.818 0.182
#
# Node number 11: 50 observations,    complexity param=0.05434783
#   predicted class=Red   expected loss=0.34  P(node) =0.4504505
#     class counts:    17    33
#    probabilities: 0.340 0.660
#   left son=22 (20 obs) right son=23 (30 obs)
#   Primary splits:
#       Pitch             < 0.07064677 to the right, improve=2.940000, (0 missing)
#       Jerk              < 0.3333333  to the right, improve=2.814384, (0 missing)
#       AccelerationSpeed < -0.3722222 to the left,  improve=2.280532, (0 missing)
#       TimeHeadway       < 2.321479   to the right, improve=2.280532, (0 missing)
#       Engine            < 1379.688   to the right, improve=2.082857, (0 missing)
#   Surrogate splits:
#       AccelerationSpeed < -0.3527778 to the left,  agree=0.76, adj=0.40, (0 split)
#       AverageVelocity   < 36.60504   to the left,  agree=0.72, adj=0.30, (0 split)
#       MaxSpeed          < 65.745     to the right, agree=0.70, adj=0.25, (0 split)
#       TimeToCollision   < 32.41485   to the left,  agree=0.70, adj=0.25, (0 split)
#       Engine            < 1370.312   to the right, agree=0.70, adj=0.25, (0 split)
#
# Node number 22: 20 observations,    complexity param=0.05434783
#   predicted class=Blue  expected loss=0.45  P(node) =0.1801802
#     class counts:    11     9
#    probabilities: 0.550 0.450
#   left son=44 (13 obs) right son=45 (7 obs)
#   Primary splits:
#       Speed           < 53.85      to the left,  improve=1.5043960, (0 missing)
#       DiffAvgSpeed    < 28.94107   to the left,  improve=1.5043960, (0 missing)
#       DistSignal      < 127.6305   to the right, improve=1.0666670, (0 missing)
#       Pitch           < 0.2325871  to the left,  improve=1.0666670, (0 missing)
#       TimeToCollision < 29.6875    to the left,  improve=0.8166667, (0 missing)
#   Surrogate splits:
#       DiffAvgSpeed    < 28.94107   to the left,  agree=1.00, adj=1.000, (0 split)
#       AverageVelocity < 49.43621   to the left,  agree=0.90, adj=0.714, (0 split)
#       MaxSpeed        < 70.685     to the left,  agree=0.85, adj=0.571, (0 split)
#       AheadDistance   < 24.25      to the left,  agree=0.85, adj=0.571, (0 split)
#       EmptinessOfRoad < 0.1586756  to the left,  agree=0.80, adj=0.429, (0 split)
#
# Node number 23: 30 observations
#   predicted class=Red   expected loss=0.2  P(node) =0.2702703
#     class counts:     6    24
#    probabilities: 0.200 0.800
#
# Node number 44: 13 observations
#   predicted class=Blue  expected loss=0.3076923  P(node) =0.1171171
#     class counts:     9     4
#    probabilities: 0.692 0.308
#
# Node number 45: 7 observations
#   predicted class=Red   expected loss=0.2857143  P(node) =0.06306306
#     class counts:     2     5
#    probabilities: 0.286 0.714
