# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from sklearn.mixture import BayesianGaussianMixture
from skbayes.mixture_models import VBBMM

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
df = pd.read_pickle("../data/middle/features.pkl")
clusters = pd.read_csv("../data/output/d5/Result/clusters.csv")
clusters.columns = ["cluster"]

# %%
idx = df.index.tolist()
cl2 = clusters[clusters["cluster"] == 2].index.tolist()
df[[i in cl2 for i in idx]]    
df[idx]
# Out:
#            red    yellow     green      slow     brake     accel  \
# 190   0.000000  1.000000  0.000000  0.000000  0.000000  0.000000
# 249   0.076923  0.692308  0.109890  0.120879  0.625000  0.375000
# 250   0.040000  0.400000  0.106667  0.453333  0.407407  0.592593
# 369   0.000000  0.219512  0.402439  0.378049  0.500000  0.500000
# 488   0.000000  0.878788  0.121212  0.000000  1.000000  0.000000
# 607   0.000000  0.021053  0.610526  0.368421  0.583333  0.416667
# 1712  0.006993  0.489510  0.244755  0.258741  0.411765  0.588235
# 1893  0.000000  0.481481  0.185185  0.333333  0.333333  0.666667
# 2014  0.000000  0.565217  0.239130  0.195652  0.750000  0.250000
# 2135  0.000000  0.330097  0.252427  0.417476  0.000000  1.000000
# 2316  0.000000  0.087137  0.265560  0.647303  0.483871  0.516129
# 2317  0.000000  0.196078  0.298039  0.505882  0.558824  0.441176
# 2318  0.000000  0.653226  0.217742  0.129032  0.250000  0.750000
# ...
