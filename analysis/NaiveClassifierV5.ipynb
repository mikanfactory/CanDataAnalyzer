# %%
library(grid)
library(rpart)
library(rpart.plot)
library(partykit)
library(lattice)
library(ggplot2)
library(caret)

# %%
set.seed(1)

# %%
invalids <- c('Time', 'Longitude', 'Latitude', 'Brake', 'Accel', 'flag', 'Curve100', 'Curve150', 'TimeHeadway')

# %%
printf <- function(...) cat(sprintf(...))

# %%
CV <- function(dfx, expr, verbose=FALSE) {        
    folds <- createFolds(dfx$flag)
    
    count <- 1
    errs <- c()
    reds <- c()
    blues <- c()
    for (ids in folds) {
        train <- dfx[-ids, ]
        test <- dfx[ids, ]
        # fit <- rpart(expr, data=train, method="class")
        fit <- rpart(expr, data=train, method="class", cp=0.014)
        p <- predict(fit, newdata=test)
        predictedFlags <- colnames(p)[max.col(p, ties.method = "first")]
        
        if (verbose) {            
            printf("Fold%d\n", count)
            result <- correctVsPredict(test, predictedFlags)
            reds <- c(reds, result[1])
            blues <- c(blues, result[2])
            count <- count + 1
            printf("\n")
        }
        
        nerr <- sum((predictedFlags == test$flag) == FALSE)
        errs <- c(errs, nerr / nrow(test))
    }
    
    return(c(mean(errs), mean(reds), mean(blues)))
}

# %%
correctVsPredict <- function(test, predictedFlags) {    
    # for All
    # nTests <- nrow(test)
    # nCorrectAll <- sum((predictedFlags == test$flag) == TRUE)
    # printf("As fo All: correct/all = %d/%d = %f\n", nCorrectAll, nTests, nCorrectAll / nTests)
    
    # for Red
    predictedRedRows <- test[predictedFlags == "Red", ]
    nCorrectReds <- sum((predictedRedRows$flag == 'Red') == TRUE)
    nPredictedReds <- nrow(predictedRedRows)
    printf("As for Red: correct/predict = %d/%d = %f\n", nCorrectReds, nPredictedReds, nCorrectReds / nPredictedReds)
    
    # for Blue
    predictedBlueRows <- test[predictedFlags == "Blue", ]
    nCorrectBlues <- sum((predictedBlueRows$flag == 'Blue') == TRUE)
    nPredictedBlues <- nrow(predictedBlueRows)
    printf("As for Blue: correct/predict = %d/%d = %f\n", nCorrectBlues, nPredictedBlues, nCorrectBlues / nPredictedBlues)
    
    c(nCorrectReds/nPredictedReds, nCorrectBlues/nPredictedBlues)
}

# %%
printRedRatios <- function(dfx) {
    nRed <- nrow(dfx[dfx$flag == "Red", ])
    nAll <- nrow(dfx)
    printf("Red/All = %d/%d = %f\n", nRed, nAll, nRed/nAll)
    printf("1 - Red/All = %d/%d = %f\n", nAll - nRed, nAll, 1 - nRed/nAll)
}

# %%
createFormula <- function(invalids, allFeatures) {
    isValidColumn <- function(x) ! x %in% invalids
    
    features <- Filter(isValidColumn, allFeatures)
    return(paste("flag ~ ", paste(features, collapse=" + ")))
}

# %% [markdown]
# # Predict Red

# %%
df3 <- read.csv("../data/middle/sp5.csv", stringsAsFactors=FALSE)

# %%
df3$flag[df3$flag == "RedA"] <- "Red"
df3$flag[df3$flag == "RedB"] <- "Red"
df3$flag[df3$flag == "BlueA"] <- "Blue"
df3$flag[df3$flag == "BlueB"] <- "Blue"
df3$flag <- as.factor(df3$flag)

# %%
allFeatures <- c(colnames(df3))
expr <- createFormula(invalids, allFeatures)

# %%
result <- CV(df3, expr, verbose=TRUE)
printRedRatios(df3)
printf("Red: Mean correct/predict = %f\n", result[2])
printf("Blue: Mean correct/predict = %f\n", result[3])
printf("CV value: %f", result[1])
# Out:
# Fold1
# As for Red: correct/predict = 49/70 = 0.700000
# As for Blue: correct/predict = 23/34 = 0.676471
#
# Fold2
# As for Red: correct/predict = 48/73 = 0.657534
# As for Blue: correct/predict = 20/32 = 0.625000
#
# Fold3
# As for Red: correct/predict = 47/71 = 0.661972
# As for Blue: correct/predict = 21/33 = 0.636364
#
# Fold4
# As for Red: correct/predict = 41/64 = 0.640625
# As for Blue: correct/predict = 22/40 = 0.550000
#
# Fold5
# As for Red: correct/predict = 50/78 = 0.641026
# As for Blue: correct/predict = 17/26 = 0.653846
#
# Fold6
# As for Red: correct/predict = 40/64 = 0.625000
# As for Blue: correct/predict = 21/40 = 0.525000
#
# Fold7
# As for Red: correct/predict = 45/71 = 0.633803
# As for Blue: correct/predict = 19/34 = 0.558824
#
# Fold8
# As for Red: correct/predict = 36/53 = 0.679245
# As for Blue: correct/predict = 28/51 = 0.549020
#
# Fold9
# As for Red: correct/predict = 47/73 = 0.643836
# As for Blue: correct/predict = 19/31 = 0.612903
#
# Fold10
# As for Red: correct/predict = 40/64 = 0.625000
# As for Blue: correct/predict = 21/40 = 0.525000
#
# Red/All = 593/1042 = 0.569098
# 1 - Red/All = 449/1042 = 0.430902
# Red: Mean correct/predict = 0.650804
# Blue: Mean correct/predict = 0.591243
# CV value: 0.372363

# %%
fit3 <- rpart(expr, data=df3, method="class")

# %%
fit3$cptable[which.min(fit3$cptable[,"xerror"]),"CP"]
# Out:
# [1] 0.01410542

# %%
printcp(fit3)
# Out:
# Classification tree:
# rpart(formula = expr, data = df3, method = "class")
#
# Variables actually used in tree construction:
#  [1] AccelerationSpeed AheadDistance     Curve             CurveAverage
#  [5] DiffAvgSpeed      DistManBicycle    DistSignal        EmptinessOfRoad
#  [9] MaxSpeed          Pitch             RiskFactor        RoadFactor
# [13] Speed             TimeToCollision
#
# Root node error: 449/1042 = 0.4309
#
# n= 1042
#
#          CP nsplit rel error  xerror     xstd
# 1  0.064588      0   1.00000 1.00000 0.035602
# 2  0.051225      1   0.93541 0.93764 0.035278
# 3  0.048998      2   0.88419 0.93096 0.035237
# 4  0.022272      3   0.83519 0.88196 0.034897
# 5  0.020045      6   0.76169 0.88196 0.034897
# 6  0.014105      7   0.74165 0.84633 0.034605
# 7  0.013363     10   0.69933 0.88419 0.034914
# 8  0.011136     11   0.68597 0.89532 0.034996
# 9  0.010022     16   0.63029 0.89087 0.034964
# 10 0.010000     18   0.61024 0.88641 0.034930

# %%
plotcp(fit3)
# Out:
# plot without title

# %%
summary(fit3)
# Out:
# Call:
# rpart(formula = expr, data = df3, method = "class")
#   n= 1042
#
#            CP nsplit rel error    xerror       xstd
# 1  0.06458797      0 1.0000000 1.0000000 0.03560167
# 2  0.05122494      1 0.9354120 0.9376392 0.03527822
# 3  0.04899777      2 0.8841871 0.9309577 0.03523711
# 4  0.02227171      3 0.8351893 0.8819599 0.03489664
# 5  0.02004454      6 0.7616927 0.8819599 0.03489664
# 6  0.01410542      7 0.7416481 0.8463252 0.03460514
# 7  0.01336303     10 0.6993318 0.8841871 0.03491362
# 8  0.01113586     11 0.6859688 0.8953229 0.03499635
# 9  0.01002227     16 0.6302895 0.8908686 0.03496369
# 10 0.01000000     18 0.6102450 0.8864143 0.03493046
#
# Variable importance
#      CurveAverage             Speed          RoadType   EmptinessOfRoad
#                10                 9                 9                 8
#      DiffAvgSpeed     AheadDistance        RiskFactor   TimeToCollision
#                 7                 7                 6                 6
#             Curve   AverageVelocity          MaxSpeed AccelerationSpeed
#                 6                 5                 5                 4
#             Pitch        RoadFactor        DistSignal    DistManBicycle
#                 4                 3                 2                 2
#          PathType   ManBicycleCount     SteeringAngle            Engine
#                 2                 1                 1                 1
#        ManBicycle              Jerk
#                 1                 1
#
# Node number 1: 1042 observations,    complexity param=0.06458797
#   predicted class=Red   expected loss=0.4309021  P(node) =1
#     class counts:   449   593
#    probabilities: 0.431 0.569
#   left son=2 (491 obs) right son=3 (551 obs)
#   Primary splits:
#       RiskFactor        < 0.4666483   to the left,  improve=18.065120, (0 missing)
#       DiffAvgSpeed      < 9.66772     to the right, improve=13.193700, (0 missing)
#       AheadDistance     < 15.65       to the right, improve= 9.802522, (0 missing)
#       MaxSpeed          < 50.52       to the left,  improve= 9.239768, (0 missing)
#       AccelerationSpeed < 0.6416667   to the left,  improve= 9.009149, (0 missing)
#   Surrogate splits:
#       TimeToCollision < 170.0767    to the right, agree=0.808, adj=0.593, (0 split)
#       AheadDistance   < 46.8        to the right, agree=0.723, adj=0.411, (0 split)
#       EmptinessOfRoad < 0.2374957   to the right, agree=0.705, adj=0.375, (0 split)
#       RoadType        < 3.5         to the right, agree=0.665, adj=0.289, (0 split)
#       RoadFactor      < 1.5         to the right, agree=0.610, adj=0.173, (0 split)
#
# Node number 2: 491 observations,    complexity param=0.05122494
#   predicted class=Blue  expected loss=0.4704684  P(node) =0.4712092
#     class counts:   260   231
#    probabilities: 0.530 0.470
#   left son=4 (466 obs) right son=5 (25 obs)
#   Primary splits:
#       Curve           < 253         to the left,  improve=12.62487, (0 missing)
#       CurveAverage    < 253         to the left,  improve=12.62487, (0 missing)
#       DiffAvgSpeed    < 14.48037    to the right, improve=12.61274, (0 missing)
#       RoadType        < 6.5         to the left,  improve=10.79420, (0 missing)
#       EmptinessOfRoad < 0.8433092   to the left,  improve=10.79420, (0 missing)
#   Surrogate splits:
#       CurveAverage    < 253         to the left,  agree=1.000, adj=1.00, (0 split)
#       RoadType        < 6.5         to the left,  agree=0.994, adj=0.88, (0 split)
#       EmptinessOfRoad < 0.8433092   to the left,  agree=0.994, adj=0.88, (0 split)
#       SteeringAngle   < -145.4      to the right, agree=0.959, adj=0.20, (0 split)
#       AverageVelocity < 3.826035    to the right, agree=0.959, adj=0.20, (0 split)
#
# Node number 3: 551 observations,    complexity param=0.01410542
#   predicted class=Red   expected loss=0.3430127  P(node) =0.5287908
#     class counts:   189   362
#    probabilities: 0.343 0.657
#   left son=6 (371 obs) right son=7 (180 obs)
#   Primary splits:
#       AheadDistance < 15.65       to the right, improve=4.625564, (0 missing)
#       Pitch         < -0.05883085 to the left,  improve=4.447316, (0 missing)
#       Curve         < 145.5       to the right, improve=4.411582, (0 missing)
#       MaxSpeed      < 49.845      to the left,  improve=4.284144, (0 missing)
#       CurveAverage  < 172.5       to the right, improve=3.982875, (0 missing)
#   Surrogate splits:
#       Speed           < 28.465      to the right, agree=0.831, adj=0.483, (0 split)
#       DiffAvgSpeed    < 3.315782    to the right, agree=0.815, adj=0.433, (0 split)
#       MaxSpeed        < 32.63       to the right, agree=0.730, adj=0.172, (0 split)
#       AverageVelocity < 8.971209    to the right, agree=0.719, adj=0.139, (0 split)
#       Engine          < 1151.562    to the right, agree=0.717, adj=0.133, (0 split)
#
# Node number 4: 466 observations,    complexity param=0.04899777
#   predicted class=Blue  expected loss=0.444206  P(node) =0.4472169
#     class counts:   259   207
#    probabilities: 0.556 0.444
#   left son=8 (266 obs) right son=9 (200 obs)
#   Primary splits:
#       DiffAvgSpeed      < 9.798412    to the right, improve=8.601946, (0 missing)
#       AccelerationSpeed < 0.5194444   to the left,  improve=7.255016, (0 missing)
#       DistSignal        < 14.61722    to the right, improve=5.887515, (0 missing)
#       Speed             < 32.15       to the right, improve=4.897950, (0 missing)
#       RoadFactor        < 2.5         to the right, improve=4.733048, (0 missing)
#   Surrogate splits:
#       Speed             < 27.94       to the right, agree=0.912, adj=0.795, (0 split)
#       AheadDistance     < 23.3        to the right, agree=0.845, adj=0.640, (0 split)
#       MaxSpeed          < 31.705      to the right, agree=0.723, adj=0.355, (0 split)
#       AverageVelocity   < 9.751344    to the right, agree=0.708, adj=0.320, (0 split)
#       AccelerationSpeed < 0.1527778   to the left,  agree=0.695, adj=0.290, (0 split)
#
# Node number 5: 25 observations
#   predicted class=Red   expected loss=0.04  P(node) =0.02399232
#     class counts:     1    24
#    probabilities: 0.040 0.960
#
# Node number 6: 371 observations,    complexity param=0.01410542
#   predicted class=Red   expected loss=0.3881402  P(node) =0.3560461
#     class counts:   144   227
#    probabilities: 0.388 0.612
#   left son=12 (181 obs) right son=13 (190 obs)
#   Primary splits:
#       MaxSpeed        < 51.39       to the left,  improve=6.795221, (0 missing)
#       TimeToCollision < 16.66656    to the left,  improve=4.366577, (0 missing)
#       Speed           < 56.12       to the left,  improve=3.670771, (0 missing)
#       RoadType        < 5.5         to the right, improve=3.585922, (0 missing)
#       SteeringAngle   < 15.8        to the left,  improve=3.510220, (0 missing)
#   Surrogate splits:
#       Speed           < 47.31       to the left,  agree=0.863, adj=0.718, (0 split)
#       AverageVelocity < 30.15494    to the left,  agree=0.827, adj=0.646, (0 split)
#       RoadType        < 3.5         to the right, agree=0.779, adj=0.547, (0 split)
#       PathType        < 53.5        to the left,  agree=0.774, adj=0.536, (0 split)
#       DiffAvgSpeed    < 25.3572     to the left,  agree=0.717, adj=0.420, (0 split)
#
# Node number 7: 180 observations
#   predicted class=Red   expected loss=0.25  P(node) =0.1727447
#     class counts:    45   135
#    probabilities: 0.250 0.750
#
# Node number 8: 266 observations,    complexity param=0.02004454
#   predicted class=Blue  expected loss=0.3609023  P(node) =0.2552783
#     class counts:   170    96
#    probabilities: 0.639 0.361
#   left son=16 (253 obs) right son=17 (13 obs)
#   Primary splits:
#       DistSignal      < 10.92793    to the right, improve=6.436776, (0 missing)
#       CurveAverage    < 101.5       to the right, improve=4.884328, (0 missing)
#       MaxSpeed        < 50.945      to the left,  improve=4.587202, (0 missing)
#       DiffAvgSpeed    < 26.79352    to the left,  improve=4.465818, (0 missing)
#       AverageVelocity < 12.21901    to the left,  improve=3.773068, (0 missing)
#
# Node number 9: 200 observations,    complexity param=0.02227171
#   predicted class=Red   expected loss=0.445  P(node) =0.1919386
#     class counts:    89   111
#    probabilities: 0.445 0.555
#   left son=18 (170 obs) right son=19 (30 obs)
#   Primary splits:
#       AccelerationSpeed < 0.5388889   to the left,  improve=8.401765, (0 missing)
#       Engine            < 1439.062    to the left,  improve=6.450083, (0 missing)
#       AheadDistance     < 70.5        to the left,  improve=5.197352, (0 missing)
#       TimeToCollision   < 103.5675    to the left,  improve=5.128227, (0 missing)
#       RoadFactor        < 2.5         to the right, improve=4.557601, (0 missing)
#   Surrogate splits:
#       Speed           < 5.695       to the right, agree=0.870, adj=0.133, (0 split)
#       ManBicycleCount < 4.5         to the left,  agree=0.865, adj=0.100, (0 split)
#       Jerk            < 1.972222    to the left,  agree=0.865, adj=0.100, (0 split)
#       AverageVelocity < 1.45039     to the right, agree=0.865, adj=0.100, (0 split)
#       MaxSpeed        < 12.255      to the right, agree=0.860, adj=0.067, (0 split)
#
# Node number 12: 181 observations,    complexity param=0.01410542
#   predicted class=Red   expected loss=0.4861878  P(node) =0.1737044
#     class counts:    88    93
#    probabilities: 0.486 0.514
#   left son=24 (57 obs) right son=25 (124 obs)
#   Primary splits:
#       Pitch         < -0.02437811 to the left,  improve=5.420187, (0 missing)
#       Engine        < 1585.938    to the left,  improve=4.575839, (0 missing)
#       SteeringAngle < 5.05        to the left,  improve=4.229546, (0 missing)
#       Jerk          < -0.4722222  to the left,  improve=3.910522, (0 missing)
#       Speed         < 34.18       to the right, improve=3.587275, (0 missing)
#   Surrogate splits:
#       CurveAverage  < 111.5       to the left,  agree=0.740, adj=0.175, (0 split)
#       RoadType      < 1.5         to the left,  agree=0.735, adj=0.158, (0 split)
#       DiffAvgSpeed  < -14.69657   to the left,  agree=0.735, adj=0.158, (0 split)
#       DistSignal    < 291.8165    to the right, agree=0.724, adj=0.123, (0 split)
#       AheadDistance < 16.15       to the left,  agree=0.713, adj=0.088, (0 split)
#
# Node number 13: 190 observations
#   predicted class=Red   expected loss=0.2947368  P(node) =0.1823417
#     class counts:    56   134
#    probabilities: 0.295 0.705
#
# Node number 16: 253 observations,    complexity param=0.01336303
#   predicted class=Blue  expected loss=0.3359684  P(node) =0.2428023
#     class counts:   168    85
#    probabilities: 0.664 0.336
#   left son=32 (213 obs) right son=33 (40 obs)
#   Primary splits:
#       CurveAverage    < 101.5       to the right, improve=5.429272, (0 missing)
#       MaxSpeed        < 50.945      to the left,  improve=4.319368, (0 missing)
#       AverageVelocity < 13.81701    to the left,  improve=3.980511, (0 missing)
#       DiffAvgSpeed    < 26.79352    to the left,  improve=3.522227, (0 missing)
#       RoadFactor      < 1.5         to the right, improve=3.125813, (0 missing)
#   Surrogate splits:
#       Curve         < 101.5       to the right, agree=0.901, adj=0.375, (0 split)
#       SteeringAngle < -6.8        to the right, agree=0.866, adj=0.150, (0 split)
#       DistTollgate  < 610         to the right, agree=0.866, adj=0.150, (0 split)
#       RoadType      < 2.5         to the right, agree=0.854, adj=0.075, (0 split)
#       Pitch         < -0.5718905  to the right, agree=0.854, adj=0.075, (0 split)
#
# Node number 17: 13 observations
#   predicted class=Red   expected loss=0.1538462  P(node) =0.01247601
#     class counts:     2    11
#    probabilities: 0.154 0.846
#
# Node number 18: 170 observations,    complexity param=0.02227171
#   predicted class=Blue  expected loss=0.4941176  P(node) =0.1631478
#     class counts:    86    84
#    probabilities: 0.506 0.494
#   left son=36 (40 obs) right son=37 (130 obs)
#   Primary splits:
#       RoadFactor      < 2.5         to the right, improve=6.234389, (0 missing)
#       AheadDistance   < 70.5        to the left,  improve=4.911850, (0 missing)
#       Engine          < 1439.062    to the left,  improve=4.115242, (0 missing)
#       Speed           < 27.56       to the left,  improve=3.852293, (0 missing)
#       TimeToCollision < 103.5675    to the left,  improve=3.675104, (0 missing)
#   Surrogate splits:
#       PathType        < 0.5         to the left,  agree=0.806, adj=0.175, (0 split)
#       AheadDistance   < 7.05        to the left,  agree=0.776, adj=0.050, (0 split)
#       DistManBicycle  < 19.6065     to the right, agree=0.776, adj=0.050, (0 split)
#       LaneCount       < 1.5         to the left,  agree=0.776, adj=0.050, (0 split)
#       AverageVelocity < 2.533956    to the left,  agree=0.776, adj=0.050, (0 split)
#
# Node number 19: 30 observations
#   predicted class=Red   expected loss=0.1  P(node) =0.02879079
#     class counts:     3    27
#    probabilities: 0.100 0.900
#
# Node number 24: 57 observations,    complexity param=0.01113586
#   predicted class=Blue  expected loss=0.3333333  P(node) =0.0547025
#     class counts:    38    19
#    probabilities: 0.667 0.333
#   left son=48 (50 obs) right son=49 (7 obs)
#   Primary splits:
#       CurveAverage    < 64          to the right, improve=4.379048, (0 missing)
#       DiffAvgSpeed    < 9.462448    to the right, improve=4.146633, (0 missing)
#       Engine          < 1418.75     to the left,  improve=3.598485, (0 missing)
#       AverageVelocity < 27.22473    to the left,  improve=3.377778, (0 missing)
#       TimeToCollision < 162.7959    to the left,  improve=2.895238, (0 missing)
#   Surrogate splits:
#       RoadType        < 1.5         to the right, agree=0.930, adj=0.429, (0 split)
#       AverageVelocity < 34.71201    to the left,  agree=0.930, adj=0.429, (0 split)
#       DiffAvgSpeed    < -11.75257   to the right, agree=0.930, adj=0.429, (0 split)
#       EmptinessOfRoad < 0.05464402  to the right, agree=0.930, adj=0.429, (0 split)
#       Curve           < 101         to the right, agree=0.912, adj=0.286, (0 split)
#
# Node number 25: 124 observations,    complexity param=0.01113586
#   predicted class=Red   expected loss=0.4032258  P(node) =0.1190019
#     class counts:    50    74
#    probabilities: 0.403 0.597
#   left son=50 (79 obs) right son=51 (45 obs)
#   Primary splits:
#       Pitch           < 0.01716418  to the right, improve=4.628193, (0 missing)
#       SteeringAngle   < 5.55        to the left,  improve=3.809327, (0 missing)
#       AverageVelocity < 23.03615    to the right, improve=3.484562, (0 missing)
#       TimeToCollision < 50.89943    to the left,  improve=3.281849, (0 missing)
#       Engine          < 1556.25     to the left,  improve=2.844086, (0 missing)
#   Surrogate splits:
#       AccelerationSpeed < 0.2777778   to the left,  agree=0.718, adj=0.222, (0 split)
#       MaxSpeed          < 24.065      to the right, agree=0.702, adj=0.178, (0 split)
#       AverageVelocity   < 7.461744    to the right, agree=0.694, adj=0.156, (0 split)
#       Speed             < 23.225      to the right, agree=0.685, adj=0.133, (0 split)
#       SteeringAngle     < 6.4         to the left,  agree=0.685, adj=0.133, (0 split)
#
# Node number 32: 213 observations
#   predicted class=Blue  expected loss=0.2910798  P(node) =0.2044146
#     class counts:   151    62
#    probabilities: 0.709 0.291
#
# Node number 33: 40 observations
#   predicted class=Red   expected loss=0.425  P(node) =0.03838772
#     class counts:    17    23
#    probabilities: 0.425 0.575
#
# Node number 36: 40 observations
#   predicted class=Blue  expected loss=0.25  P(node) =0.03838772
#     class counts:    30    10
#    probabilities: 0.750 0.250
#
# Node number 37: 130 observations,    complexity param=0.02227171
#   predicted class=Red   expected loss=0.4307692  P(node) =0.1247601
#     class counts:    56    74
#    probabilities: 0.431 0.569
#   left son=74 (37 obs) right son=75 (93 obs)
#   Primary splits:
#       TimeToCollision < 103.2307    to the left,  improve=6.204297, (0 missing)
#       EmptinessOfRoad < 0.336005    to the left,  improve=4.606660, (0 missing)
#       Speed           < 26.635      to the left,  improve=3.776068, (0 missing)
#       Pitch           < 0.1753731   to the left,  improve=3.617094, (0 missing)
#       AheadDistance   < 70.5        to the left,  improve=3.253846, (0 missing)
#   Surrogate splits:
#       RiskFactor      < 0.4156539   to the right, agree=0.746, adj=0.108, (0 split)
#       Speed           < 5.94        to the left,  agree=0.738, adj=0.081, (0 split)
#       Engine          < 884.375     to the left,  agree=0.738, adj=0.081, (0 split)
#       Limit30Sign     < 0.5         to the right, agree=0.723, adj=0.027, (0 split)
#       AverageVelocity < 3.979106    to the left,  agree=0.723, adj=0.027, (0 split)
#
# Node number 48: 50 observations
#   predicted class=Blue  expected loss=0.26  P(node) =0.04798464
#     class counts:    37    13
#    probabilities: 0.740 0.260
#
# Node number 49: 7 observations
#   predicted class=Red   expected loss=0.1428571  P(node) =0.00671785
#     class counts:     1     6
#    probabilities: 0.143 0.857
#
# Node number 50: 79 observations,    complexity param=0.01113586
#   predicted class=Blue  expected loss=0.4936709  P(node) =0.07581574
#     class counts:    40    39
#    probabilities: 0.506 0.494
#   left son=100 (18 obs) right son=101 (61 obs)
#   Primary splits:
#       Speed           < 40.89       to the right, improve=3.435383, (0 missing)
#       DistSignal      < 78.1195     to the right, improve=3.358606, (0 missing)
#       AverageVelocity < 28.47431    to the right, improve=3.193671, (0 missing)
#       LaneCount       < 2.5         to the left,  improve=2.789537, (0 missing)
#       AheadDistance   < 28.15       to the right, improve=2.680899, (0 missing)
#   Surrogate splits:
#       DiffAvgSpeed    < 19.11223    to the right, agree=0.861, adj=0.389, (0 split)
#       MaxSpeed        < 47.735      to the right, agree=0.823, adj=0.222, (0 split)
#       Curve           < 253         to the right, agree=0.810, adj=0.167, (0 split)
#       CurveAverage    < 253         to the right, agree=0.810, adj=0.167, (0 split)
#       EmptinessOfRoad < 0.1586756   to the left,  agree=0.810, adj=0.167, (0 split)
#
# Node number 51: 45 observations
#   predicted class=Red   expected loss=0.2222222  P(node) =0.04318618
#     class counts:    10    35
#    probabilities: 0.222 0.778
#
# Node number 74: 37 observations
#   predicted class=Blue  expected loss=0.3243243  P(node) =0.03550864
#     class counts:    25    12
#    probabilities: 0.676 0.324
#
# Node number 75: 93 observations,    complexity param=0.01002227
#   predicted class=Red   expected loss=0.3333333  P(node) =0.08925144
#     class counts:    31    62
#    probabilities: 0.333 0.667
#   left son=150 (33 obs) right son=151 (60 obs)
#   Primary splits:
#       DistManBicycle  < 2.506562    to the right, improve=3.381818, (0 missing)
#       Pitch           < 0.00783582  to the left,  improve=3.179487, (0 missing)
#       ManBicycleCount < 0.5         to the right, improve=2.606240, (0 missing)
#       ManBicycle      < 0.5         to the right, improve=2.606240, (0 missing)
#       RiskFactor      < 0.4323661   to the left,  improve=2.214286, (0 missing)
#   Surrogate splits:
#       ManBicycleCount < 0.5         to the right, agree=0.978, adj=0.939, (0 split)
#       ManBicycle      < 0.5         to the right, agree=0.978, adj=0.939, (0 split)
#       Speed           < 13.605      to the left,  agree=0.731, adj=0.242, (0 split)
#       AheadDistance   < 13.4        to the left,  agree=0.731, adj=0.242, (0 split)
#       MaxSpeed        < 19.54       to the left,  agree=0.710, adj=0.182, (0 split)
#
# Node number 100: 18 observations
#   predicted class=Blue  expected loss=0.2222222  P(node) =0.01727447
#     class counts:    14     4
#    probabilities: 0.778 0.222
#
# Node number 101: 61 observations,    complexity param=0.01113586
#   predicted class=Red   expected loss=0.4262295  P(node) =0.05854127
#     class counts:    26    35
#    probabilities: 0.426 0.574
#   left son=202 (43 obs) right son=203 (18 obs)
#   Primary splits:
#       EmptinessOfRoad < 0.2586756   to the right, improve=3.440717, (0 missing)
#       Speed           < 36.23       to the left,  improve=3.412877, (0 missing)
#       Engine          < 1318.75     to the left,  improve=3.214853, (0 missing)
#       AheadDistance   < 17          to the left,  improve=2.936595, (0 missing)
#       Jerk            < 1.166667    to the left,  improve=2.545869, (0 missing)
#   Surrogate splits:
#       RoadType          < 3.5         to the right, agree=0.754, adj=0.167, (0 split)
#       AccelerationSpeed < 0.1888889   to the left,  agree=0.754, adj=0.167, (0 split)
#       AheadDistance     < 16.15       to the right, agree=0.738, adj=0.111, (0 split)
#       RiskFactor        < 0.490667    to the right, agree=0.738, adj=0.111, (0 split)
#       MaxSpeed          < 48.97       to the left,  agree=0.738, adj=0.111, (0 split)
#
# Node number 150: 33 observations,    complexity param=0.01002227
#   predicted class=Blue  expected loss=0.4848485  P(node) =0.03166987
#     class counts:    17    16
#    probabilities: 0.515 0.485
#   left son=300 (13 obs) right son=301 (20 obs)
#   Primary splits:
#       CurveAverage    < 176         to the right, improve=4.700233, (0 missing)
#       DistManBicycle  < 8.528125    to the left,  improve=2.734848, (0 missing)
#       EmptinessOfRoad < 0.3092216   to the left,  improve=2.651515, (0 missing)
#       RiskFactor      < 0.3998395   to the left,  improve=2.462870, (0 missing)
#       AverageVelocity < 6.536778    to the right, improve=2.123737, (0 missing)
#   Surrogate splits:
#       Engine         < 1265.625    to the right, agree=0.818, adj=0.538, (0 split)
#       DistManBicycle < 6.92925     to the left,  agree=0.788, adj=0.462, (0 split)
#       RoadType       < 4.5         to the right, agree=0.758, adj=0.385, (0 split)
#       DiffAvgSpeed   < 1.825808    to the right, agree=0.758, adj=0.385, (0 split)
#       Speed          < 24.805      to the right, agree=0.727, adj=0.308, (0 split)
#
# Node number 151: 60 observations
#   predicted class=Red   expected loss=0.2333333  P(node) =0.05758157
#     class counts:    14    46
#    probabilities: 0.233 0.767
#
# Node number 202: 43 observations,    complexity param=0.01113586
#   predicted class=Blue  expected loss=0.4651163  P(node) =0.04126679
#     class counts:    23    20
#    probabilities: 0.535 0.465
#   left son=404 (34 obs) right son=405 (9 obs)
#   Primary splits:
#       Speed           < 36.52       to the left,  improve=4.088159, (0 missing)
#       Engine          < 1323.438    to the left,  improve=3.268156, (0 missing)
#       DiffAvgSpeed    < 13.81633    to the left,  improve=2.642102, (0 missing)
#       Jerk            < 1.083333    to the left,  improve=2.569952, (0 missing)
#       TimeToCollision < 33.78605    to the left,  improve=2.569952, (0 missing)
#   Surrogate splits:
#       BrakeCar     < 0.5         to the left,  agree=0.860, adj=0.333, (0 split)
#       Jerk         < 1.166667    to the left,  agree=0.837, adj=0.222, (0 split)
#       CurveAverage < 96.5        to the right, agree=0.837, adj=0.222, (0 split)
#       DiffAvgSpeed < 18.30452    to the left,  agree=0.837, adj=0.222, (0 split)
#       RoadFactor   < 3.5         to the left,  agree=0.837, adj=0.222, (0 split)
#
# Node number 203: 18 observations
#   predicted class=Red   expected loss=0.1666667  P(node) =0.01727447
#     class counts:     3    15
#    probabilities: 0.167 0.833
#
# Node number 300: 13 observations
#   predicted class=Blue  expected loss=0.1538462  P(node) =0.01247601
#     class counts:    11     2
#    probabilities: 0.846 0.154
#
# Node number 301: 20 observations
#   predicted class=Red   expected loss=0.3  P(node) =0.01919386
#     class counts:     6    14
#    probabilities: 0.300 0.700
#
# Node number 404: 34 observations
#   predicted class=Blue  expected loss=0.3529412  P(node) =0.03262956
#     class counts:    22    12
#    probabilities: 0.647 0.353
#
# Node number 405: 9 observations
#   predicted class=Red   expected loss=0.1111111  P(node) =0.008637236
#     class counts:     1     8
#    probabilities: 0.111 0.889

# %%
plot(fit3, uniform=TRUE, main="Classification Tree")
text(fit3, use.n=TRUE, all=TRUE, cex=.8)
# Out:
# Plot with title “Classification Tree”
